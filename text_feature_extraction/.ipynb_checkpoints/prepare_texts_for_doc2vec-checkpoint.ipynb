# %%
import nltk
from nltk import WordNetLemmatizer, FreqDist
import pandas as pd
import os
import re

# %%
cwd=os.getcwd()
path_to_raw_texts=os.path.join(cwd,"texts/raw_texts")
preprocessed_texts_file=os.path.join(cwd,"texts/preprocessed_texts_for_doc2vec.pkl")
stopwords=['inch','pound','pint','tbsp','tablespoon','tsp','teaspoon',
           'g','gram','kg','f','l','ll','ml','t','s','cm','mm','milliliter',
           'sec','m','minute','min','h','hour','%','eel','pre','lb','oz',
           '–','-','c',';','...','x','*','+','!','?','<','>',
           'ºf', 'ºc',
           'i','ii','iii','iv','v','vi','vii','viii',
           'ix','xi','xii','xiii','viiii','xiv','®','e','re',
           '’','’’','/','‘','‘‘',':','°', '½','¼','⅛',
           'spoon','dish','fork','knife','cup','cover','pan','jug','plate',
           'half','quarter',
           'first','second','third',
           'step','ingridients','method',
           'temperature','degree','doneness','room','flavor','heat','bowl','result','ve','one','size','chef','ease','hand',
           'transfer','edge','glass','plastic','repeat','use','side','line','content','kitchen',
           'video','underside','photo','motion','place','top','cooking','thick','closest',
           'need','centre','way','grade','tip','lock','shape','length','width','lengthwise',
           'log','lengthways', 'crosswise','front','start','finish','cloth','film','board',
           'ingredient','cook','center','taste','pair','segment','chip','presentation','gras',
           'ounce','end','time','package','serving','serve','medium','good','recipe']

word_importance_low_bound=3

# %%
def read_recipe_texts(path_to_raw_texts):
    return nltk.corpus.reader.plaintext.PlaintextCorpusReader(path_to_raw_texts,'.*\.txt')

def basic_text_preprocessing(corpus):
    labels=[]
    text_names=[]
    preprocessed_texts=[]
    all_words_in_food_categories={}
    
    abspaths=corpus.abspaths()
    lemmatizer = WordNetLemmatizer()

    for path_of_raw_recipe in abspaths:
    
        splitted_path=re.split('\/',path_of_raw_recipe)
        length_of_path=len(splitted_path)
        food_category=splitted_path[length_of_path-2]
        labels.append(food_category)
        text_name=splitted_path[length_of_path-1]
        text_names.append(text_name)
    
        recipe_text=corpus.words(path_of_raw_recipe)
    
        text_without_numbers=[]
        for word in recipe_text:
            text_without_numbers.append(re.sub(r'\d+', '', word)) #sushi2 -> sushi
        
        lowercase_text=' '.join(text_without_numbers).lower()
        tokens = nltk.word_tokenize(lowercase_text)
        tags = nltk.pos_tag(tokens)
        nouns = [word for word,pos in tags if (pos == 'NN'  or  pos == 'NNS')]
    
        l_nouns=[]
        for n in nouns:
            l_nouns.append(lemmatizer.lemmatize(n))
        
        filtered_nouns = [l_noun for l_noun in l_nouns if l_noun not in stopwords]
    
        all_words_in_food_categories.setdefault(food_category,[])
        all_words_in_food_categories[food_category].extend(filtered_nouns)
        
        preprocessed_texts.append(filtered_nouns)  
        
    return labels,text_names,preprocessed_texts,all_words_in_food_categories

def find_most_common_word_in_food_categories(all_words_in_food_categories):
    dict_category_common_words={}
    for category,all_words_in_food_category in all_words_in_food_categories.items():
        words_frequency_distribution=FreqDist(all_words_in_food_category)
        common_words=[word for word, num_of_occur in words_frequency_distribution.items() if
                    num_of_occur > word_importance_low_bound]
        dict_category_common_words[category]=common_words
    return dict_category_common_words

def filter_rare_words_in_recipes(labels,preprocessed_texts,common_words_in_food_categories):
    important_words_in_texts=[]
    num_of_important_words_in_texts=[]
    
    for ix in range(len(preprocessed_texts)):
        food_category=labels[ix]
        basically_preprocessed_text=preprocessed_texts[ix]
        common_words_for_food_category=common_words_in_food_categories[food_category]
        important_words=[word for word in basically_preprocessed_text if word in common_words_for_food_category]
        important_words_in_texts.append(important_words)
        num_of_important_words_in_texts.append(len(important_words))
        
    return important_words_in_texts, num_of_important_words_in_texts

# %%
corpus = read_recipe_texts(path_to_raw_texts)

labels,text_names,preprocessed_texts,all_words_in_food_categories=basic_text_preprocessing(corpus)

common_words_in_food_categories=find_most_common_word_in_food_categories(all_words_in_food_categories)
    
important_words_in_texts,num_of_important_words_in_texts=filter_rare_words_in_recipes(labels,preprocessed_texts,common_words_in_food_categories)
print(important_words_in_texts)
# Out:
# [['apple', 'pie', 'recipe', 'dessert', 'cinnamon', 'roll', 'egg', 'milk', 'cinnamon', 'vanilla', 'extract', 'butter', 'smith', 'apple', 'sugar', 'vanilla', 'ice', 'cream', 'roll', 'dough', 'egg', 'milk', 'cinnamon', 'vanilla', 'smith', 'apple', 'sugar', 'vanilla', 'ice', 'cream', 'preheat', 'cinnamon', 'roll', 'dough', 'strip', 'strip', 'piece', 'piece', 'cinnamon', 'roll', 'egg', 'milk', 'cinnamon', 'extract', 'butter', 'apple', 'sugar', 'sugar', 'cinnamon', 'roll', 'dough', 'piece', 'egg', 'mixture', 'apple', 'brown', 'cream', 'enjoy'], ['apple', 'pie', 'dessert', 'apple', 'powder', 'butter', 'sugar', 'cinnamon', 'salt', 'pastry', 'egg', 'paper', 'apple', 'butter', 'sugar', 'cinnamon', 'nutmeg', 'salt', 'sheet', 'puff', 'pastry', 'egg', 'egg', 'paper', 'peel', 'apple', 'water', 'powder', 'powder', 'water', 'mixture', 'butter', 'sugar', 'cinnamon', 'nutmeg', 'salt', 'whisk', 'mixture', 'apple', 'stir', 'pastry', 'preheat', 'pastry', 'rectangle', 'apple', 'mixture', 'rectangle', 'water', 'rectangle', 'apple', 'rectangle', 'rectangle', 'filling', 'whisk', 'egg', 'pie', 'sheet', 'pie', 'bake', 'brown', 'rectangle', 'paper', 'rectangle', 'apple', 'pie', 'enjoy'], ['apple', 'pie', 'dessert', 'puff', 'pastry', 'butter', 'sugar', 'apple', 'cinnamon', 'ground', 'sheet', 'pastry', 'butter', 'sugar', 'apple', 'mix', 'puff', 'pastry', 'slice', 'apple', 'butter', 'pastry', 'sugar', 'pastry', 'mix', 'apple', 'pastry', 'enjoy'], ['caramel', 'apple', 'pie', 'recipe', 'dessert', 'granny', 'smith', 'apple', 'juice', 'flour', 'sugar', 'ground', 'cinnamon', 'ground', 'pie', 'crust', 'egg', 'cream', 'brown', 'sugar', 'butter', 'granny', 'smith', 'apple', 'juice', 'sugar', 'ground', 'cinnamon', 'ground', 'pie', 'crust', 'egg', 'cream', 'butter', 'salt', 'preheat', 'oven', 'apple', 'slice', 'juice', 'flour', 'sugar', 'cinnamon', 'apple', 'pie', 'crust', 'pie', 'apple', 'slice', 'bottom', 'crust', 'pie', 'crust', 'apple', 'slice', 'dough', 'crust', 'pie', 'egg', 'pie', 'crust', 'brown', 'pastry', 'saucepan', 'cream', 'sugar', 'sugar', 'whisk', 'butter', 'boil', 'caramel', 'caramel', 'sauce', 'cool', 'pie', 'salt', 'slice', 'enjoy'], ['cooker', 'apple', 'recipe', 'dessert', 'apple', 'pie', 'filling', 'cake', 'mix', 'butter', 'vanilla', 'ice', 'cream', 'apple', 'pie', 'butter', 'apple', 'pie', 'filling', 'mix', 'butter', 'cooker', 'bake', 'vanilla', 'ice', 'cream', 'cream', 'enjoy'], ['cooker', 'cranberry', 'apple', 'pie', 'recipe', 'dessert', 'cranberry', 'sauce', 'apple', 'pie', 'filling', 'cake', 'mix', 'butter', 'vanilla', 'ice', 'cream', 'cranberry', 'apple', 'pie', 'cake', 'mix', 'butter', 'vanilla', 'ice', 'cream', 'cranberry', 'sauce', 'apple', 'pie', 'cooker', 'bottom', 'cake', 'mix', 'cooker', 'apple', 'cranberry', 'slice', 'butter', 'slice', 'mix', 'vanilla', 'ice', 'cream', 'cream', 'enjoy'], ['apple', 'pie', 'recipe', 'dessert', 'flour', 'sugar', 'salt', 'butter', 'ice', 'water', 'granny', 'smith', 'apple', 'sugar', 'lemon', 'cornstarch', 'lemon', 'oil', 'salt', 'flour', 'sugar', 'salt', 'butter', 'water', 'granny', 'smith', 'apple', 'sugar', 'juice', 'oil', 'salt', 'crust', 'flour', 'sugar', 'salt', 'butter', 'flour', 'piece', 'ice', 'water', 'mix', 'dough', 'dough', 'oven', 'filling', 'peel', 'core', 'apple', 'slice', 'sugar', 'lemon', 'cornstarch', 'juice', 'oil', 'salt', 'apple', 'surface', 'roll', 'dough', 'round', 'pie', 'bottom', 'dough', 'bottom', 'pie', 'crust', 'apple', 'crust', 'crust', 'dough', 'crust', 'crust', 'oil', 'sugar', 'cinnamon', 'crust', 'bake', 'crust', 'brown', 'cool', 'slice', 'enjoy'], ['apple', 'pie', 'bread', 'recipe', 'dessert', 'bread', 'egg', 'milk', 'vanilla', 'extract', 'cinnamon', 'smith', 'apple', 'sugar', 'cornstarch', 'vanilla', 'ice', 'cream', 'caramel', 'sauce', 'slice', 'egg', 'milk', 'vanilla', 'cinnamon', 'granny', 'smith', 'apple', 'sugar', 'vanilla', 'ice', 'cream', 'caramel', 'preheat', 'bread', 'egg', 'milk', 'vanilla', 'cinnamon', 'bread', 'stir', 'bread', 'milk', 'mixture', 'bread', 'round ...

# %%
dict_preprocessed_texts = {
    'text_names': text_names,
    'labels' : labels,
    'preprocessed_texts' : important_words_in_texts,
    'number_of_important_words' : num_of_important_words_in_texts
}
    
df_preprocessed_texts=pd.DataFrame(dict_preprocessed_texts)  

print("Saving preprocessed texts pandas dataframe to: ", preprocessed_texts_file)
df_preprocessed_texts.to_pickle(preprocessed_texts_file)

print("Preprocessed texts pandas dataframe: \n")
df_preprocessed_texts
# Out:
# Saving preprocessed texts pandas dataframe to:  /notebooks/school/text_feature_extraction/texts/preprocessed_texts_for_doc2vec.pkl
# Preprocessed texts pandas dataframe:
#             labels  number_of_important_words  \
# 0        apple_pie                         58
# 1        apple_pie                         66
# 2        apple_pie                         28
# 3        apple_pie                         78
# 4        apple_pie                         28
# 5        apple_pie                         46
# 6        apple_pie                         82
# 7        apple_pie                         60
# 8        apple_pie                         69
# 9        apple_pie                         85
# 10       apple_pie                         54
# 11       apple_pie                         41
# 12       apple_pie                         99
# 13       apple_pie                         70
# 14       apple_pie                         43
# 15      cheesecake                         39
# 16      cheesecake                         54
# 17      cheesecake                         46
# 18      cheesecake                         49
# 19      cheesecake                         55
# 20      cheesecake                         44
# 21      cheesecake                         54
# 22      cheesecake                         32
# 23      cheesecake                         51
# 24      cheesecake                         40
# 25      cheesecake                         55
# 26   chicken_curry                        136
# 27   chicken_curry                         43
# 28   chicken_curry                         72
# 29   chicken_curry                        110
# ..             ...                        ...
# 286          tacos                         30
# 287          tacos                         35
# 288          tacos                         61
# 289          tacos                         42
# 290          tacos                         54
# 291          tacos                         59
# 292          tacos                         75
# 293          tacos                         24
# 294          tacos                         41
# 295          tacos                         38
# 296       tiramisu                         34
# 297       tiramisu                         46
# 298       tiramisu                         31
# 299       tiramisu                         36
# 300       tiramisu                         46
# 301       tiramisu                         28
# 302       tiramisu                         22
# 303       tiramisu                         46
# 304       tiramisu                         70
# 305       tiramisu                         38
# 306        waffles                         25
# 307        waffles                         24
# 308        waffles                         49
# 309        waffles                         15
# 310        waffles                         39
# 311        waffles                         22
# 312        waffles                         42
# 313        waffles                         30
# 314        waffles                         40
# 315        waffles                         27
#
#                                     preprocessed_texts text_names
# 0    [apple, pie, recipe, dessert, cinnamon, roll, ...      1.txt
# 1    [apple, pie, dessert, apple, powder, butter, s...     10.txt
# 2    [apple, pie, dessert, puff, pastry, butter, su...     11.txt
# 3    [caramel, apple, pie, recipe, dessert, granny,...     12.txt
# 4    [cooker, apple, recipe, dessert, apple, pie, f...     13.txt
# 5    [cooker, cranberry, apple, pie, recipe, desser...     14.txt
# 6    [apple, pie, recipe, dessert, flour, sugar, sa...     15.txt
# 7    [apple, pie, bread, recipe, dessert, bread, eg...      2.txt
# 8    [apple, pie, recipe, bakery, pie, crust, cream...      3.txt
# 9    [apple, pie, recipe, bakery, vanilla, ice, cre...      4.txt
# 10   [apple, pie, dessert, graham, cracker, sugar, ...      5.txt
# 11   [apple, pie, recipe, dessert, granny, smith, a...      6.txt
# 12   [apple, pie, dumpling, recipe, bakery, apple, ...      7.txt
# 13   [caramel, apple, pie, recipe, bakery, apple, l...      8.txt
# 14   [cinnamon, roll, apple, pie, recipe, bakery, s...      9.txt
# 15   [recipe, dessert, butter, graham, cracker, cre...      1.txt
# 16   [bake, cherry, cheesecake, recipe, dessert, gr...     10.txt
# 17   [box, brownie, cheesecake, recipe, brownie, mi...     11.txt
# 18   [cheesecake, recipe, dessert, mix, cream, chee...      2.txt
# 19   [cherry, cheesecake, recipe, dessert, dessert,...      3.txt
# 20   [chocolate, recipe, dessert, brownie, mix, cre...      4.txt
# 21   [mini, cheesecake, dessert, biscuit, butter, c...      5.txt
# 22   [mini, cheesecake, dessert, cream, cheese, cre...      6.txt
# 23   [mini, bake, cheesecake, dessert, butter, milk...      7.txt
# 24   [mini, peanut, butter, cheesecake, cracker, cr...      8.txt
# 25   [nibble, brownie, dessert, sugar, butter, choc...      9.txt
# 26   [chicken, curry, recipe, dinner, salt, ground,...      1.txt
# 27   [chicken, curry, recipe, dinner, oil, chicken,...      2.txt
# 28   [coconut, chicken, curry, recipe, chicken, oni...      3.txt
# 29   [chicken, curry, dinner, coconut, oil, cinnamo...      4.txt
# ..                                                 ...        ...
# 286  [cauliflower, tortilla, taco, recipe, dinner, ...      1.txt
# 287  [bean, potato, taco, recipe, lunch, potato, oi...     10.txt
# 288  [chicken, taco, recipe, lunch, chicken, bell, ...      2.txt
# 289  [cilantro, lime, chicken, taco, recipe, chicke...      3.txt
# 290  [potato, taco, recipe, dinner, potato, cream, ...      4.txt
# 291  [decker, potato, taco, recipe, dinner, potato,...      5.txt
# 292  [taco, cilantro, sauce, recipe, lunch, shrimp,...      6.txt
# 293  [chicken, taco, recipe, tortilla, butter, chic...      7.txt
# 294  [chicken, taco, recipe, dinner, chicken, onion...      8.txt
# 295  [chicken, taco, recipe, lunch, chicken, onion,...      9.txt
# 296  [egg, yolk, sugar, mascarpone, egg, white, cre...      1.txt
# 297  [strawberry, confectioner, sugar, mascarpone, ...     10.txt
# 298  [egg, yolk, sugar, cream, vanilla, mascarpone,...      2.txt
# 299  [egg, yolk, sugar, cream, ladyfinger, coffee, ...      3.txt
# 300  [sugar, egg, espresso, sugar, ladyfinger, powd...      4.txt
# 301  [coffee, liqueur, cream, cheese, cream, ladyfi...      5.txt
# 302  [egg, yolk, sugar, mascarpone, ladyfinger, cof...      6.txt
# 303  [strawberry, confectioner, sugar, mascarpone, ...      7.txt
# 304  [cake, cake, coffee, powder, coffee, coffee, c...      8.txt
# 305  [vanilla, wafer, coffee, water, cream, cheese,...      9.txt
# 306  [brownie, waffle, recipe, brownie, mix, vanill...      1.txt
# 307  [waffle, recipe, breakfast, egg, salt, pepper,...     10.txt
# 308  [chicken, breakfast, syrup, salt, pepper, pepp...      2.txt
# 309  [cinnamon, roll, waffle, cinnamon, roll, dough...      3.txt
# 310  [pancake, mix, recipe, breakfast, oat, milk, e...      4.txt
# 311  [waffle, recipe, breakfast, bread, egg, slice,...      5.txt
# 312  [mozzarella, waffle, mozzarella, cheese, flour...      6.txt
# 313  [pizza, waffle, pizza, dough, marinara, sauce,...      7.txt
# 314  [waffle, breakfast, mix, powder, oil, egg, pec...      8.txt
# 315  [waffle, recipe, mix, egg, oil, milk, egg, oil...      9.txt
#
# [316 rows x 4 columns]
