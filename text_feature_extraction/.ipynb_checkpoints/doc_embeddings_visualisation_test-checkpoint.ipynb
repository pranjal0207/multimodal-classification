# %%
import os
import pandas as pd
import numpy as np
from tensorflow.python import pywrap_tensorflow
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import plotly
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.plotly as py
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
def show_word_and_doc_embeddings():
    for tensor_name in var_to_shape_map:
        print("tensor_name: ", tensor_name) # get the variable name
        print(reader.get_tensor(tensor_name)) # get the variable
    
cwd=os.getcwd()
number_of_crossvalidation_run=1
models_folder_name_train = os.path.join(cwd,'models','train',str(number_of_crossvalidation_run))
models_folder_name_test = os.path.join(cwd,'models','test',str(number_of_crossvalidation_run))
path_to_preprocessed_texts_train=os.path.join(models_folder_name_train,'recipes_train_dataset.pkl')
path_to_preprocessed_texts_test=os.path.join(models_folder_name_test,'recipes_test_dataset.pkl')
path_to_saved_model = os.path.join(models_folder_name_test,'doc2vec_recipes_checkpoint.ckpt')
path_to_save_docs_embeddings_pkl=os.path.join(models_folder_name_test,'docs_extracted_features.pkl')

reader = pywrap_tensorflow.NewCheckpointReader(path_to_saved_model)
var_to_shape_map = reader.get_variable_to_shape_map() # 'var_to_shape_map' is a dictionary containing every saved tensor of the model

docs_extracted_features_all = reader.get_tensor('doc_embeddings_all')
docs_extracted_features_all = docs_extracted_features_all.tolist() 
    
df_preprocessed_texts_train = pd.read_pickle(path_to_preprocessed_texts_train)
df_preprocessed_texts_test = pd.read_pickle(path_to_preprocessed_texts_test)
number_of_test_docs=df_preprocessed_texts_test.labels.count()
print(number_of_test_docs)
print(np.shape(docs_extracted_features_all))
df_preprocessed_texts_test
# Out:
# 52
# (316, 27)
#                   labels  number_of_important_words  \
# 0              apple_pie                         58
# 4              apple_pie                         28
# 8              apple_pie                         69
# 20            cheesecake                         44
# 22            cheesecake                         32
# 28         chicken_curry                         72
# 38         chicken_wings                         40
# 39         chicken_wings                         63
# 47         chicken_wings                         35
# 54        chocolate_cake                         31
# 60        chocolate_cake                         91
# 67      chocolate_mousse                         24
# 73          deviled_eggs                         41
# 85             dumplings                        108
# 93          french_toast                         37
# 99          french_toast                         47
# 105           fried_rice                         48
# 111           fried_rice                         35
# 123        frozen_yogurt                         15
# 125        frozen_yogurt                         18
# 133         garlic_bread                         79
# 138         garlic_bread                         58
# 147            hamburger                        109
# 152               hummus                         52
# 157               hummus                         30
# 163              lasagna                         63
# 166              lasagna                         71
# 172  macaroni_and_cheese                         37
# 177  macaroni_and_cheese                         46
# 182  macaroni_and_cheese                         53
# 190             macarons                         71
# 197               nachos                         54
# 202               nachos                         76
# 210          onion_rings                         50
# 217             pancakes                         27
# 229                pizza                        108
# 233              sashimi                         56
# 239              sashimi                         57
# 242                steak                         28
# 244                steak                         33
# 246                steak                         51
# 256                steak                         27
# 267                sushi                        158
# 274                sushi                         86
# 277                sushi                         61
# 284                sushi                         98
# 287                tacos                         35
# 293                tacos                         24
# 302             tiramisu                         22
# 303             tiramisu                         46
# 313              waffles                         30
# 315              waffles                         27
#
#                                     preprocessed_texts text_names
# 0    [apple, pie, recipe, dessert, cinnamon, roll, ...      1.txt
# 4    [cooker, apple, recipe, dessert, apple, pie, f...     13.txt
# 8    [apple, pie, recipe, bakery, pie, crust, cream...      3.txt
# 20   [chocolate, recipe, dessert, brownie, mix, cre...      4.txt
# 22   [mini, cheesecake, dessert, cream, cheese, cre...      6.txt
# 28   [coconut, chicken, curry, recipe, chicken, oni...      3.txt
# 38   [root, beer, wing, recipe, appetizer, chicken,...     13.txt
# 39   [mango, chicken, wing, recipe, appetizer, flou...     14.txt
# 47   [chicken, wing, recipe, appetizer, chicken, wi...      6.txt
# 54   [chocolate, recipe, chocolate, cake, mix, milk...      3.txt
# 60   [bake, chocolate, cake, recipe, dessert, choco...      9.txt
# 67   [strawberry, chocolate, mousse, recipe, desser...      7.txt
# 73   [egg, recipe, appetizer, egg, salt, pepper, to...      4.txt
# 85   [dumpling, water, gelatin, powder, soy, sauce,...      7.txt
# 93   [toast, recipe, breakfast, egg, milk, syrup, v...     14.txt
# 99   [toast, recipe, breakfast, egg, cream, sugar, ...      7.txt
# 105  [potato, rice, recipe, potato, oil, onion, car...     12.txt
# 111  [chicken, rice, recipe, chicken, rice, recipe,...      5.txt
# 123  [strawberry, yogurt, recipe, snack, strawberry...      4.txt
# 125  [strawberry, banana, yogurt, recipe, snack, st...      6.txt
# 133  [chicken, bread, recipe, appetizer, chicken, f...      4.txt
# 138  [steak, stuffed, bread, recipe, appetizer, oil...      9.txt
# 147  [burger, recipe, dinner, chickpea, onion, pars...      9.txt
# 152  [beet, hummus, recipe, snack, garbanzo, bean, ...      2.txt
# 157  [hummus, carrot, snack, chickpea, oil, lemon, ...      7.txt
# 163  [chicken, lasagna, recipe, dinner, salt, peppe...      2.txt
# 166  [lasagne, roll, dinner, beef, onion, tomato, o...      5.txt
# 172  [mac, amp, recipe, macaroni, cream, cheese, ch...     10.txt
# 177  [mac, recipe, potato, carrot, onion, cashew, p...     15.txt
# 182  [cheese, mac, recipe, macaroni, milk, egg, but...      6.txt
# 190  [macarons, bakery, almond, meal, sugar, egg, s...      5.txt
# 197  [steak, nacho, recipe, appetizer, steak, salt,...     12.txt
# 202  [mustard, chicken, tater, tot, recipe, appetiz...      6.txt
# 210  [onion, ring, recipe, salt, powder, onion, flo...      5.txt
# 217  [blueberry, pancake, breakfast, banana, oat, e...      4.txt
# 229  [pizza, recipe, dinner, water, sugar, yeast, f...      7.txt
# 233  [sashimi, salmon, filet, sesame, seed, oil, se...      2.txt
# 239  [tuna, piece, piece, ginger, soy, sauce, sauce...      8.txt
# 242  [onion, clove, oil, vinegar, soy, sauce, musta...     10.txt
# 244  [recipe, dinner, sirloin, steak, kosher, salt,...     12.txt
# 246  [pepper, steak, recipe, dinner, strip, steak, ...     14.txt
# 256  [clove, ginger, onion, soy, sauce, oil, meat, ...      3.txt
# 267  [breast, sesame, oil, oil, sea, salt, teriyaki...     13.txt
# 274  [rice, water, piece, rice, vinegar, sugar, sal...      2.txt
# 277  [spicy, tuna, roll, recipe, dinner, sushi, ric...     22.txt
# 284  [avocado, nori, season, rice, rice, recipe, to...      8.txt
# 287  [bean, potato, taco, recipe, lunch, potato, oi...     10.txt
# 293  [chicken, taco, recipe, tortilla, butter, chic...      7.txt
# 302  [egg, yolk, sugar, mascarpone, ladyfinger, cof...      6.txt
# 303  [strawberry, confectioner, sugar, mascarpone, ...      7.txt
# 313  [pizza, waffle, pizza, dough, marinara, sauce,...      7.txt
# 315  [waffle, recipe, mix, egg, oil, milk, egg, oil...      9.txt

# %%
path_to_docs_extracted_features_train=os.path.join(models_folder_name_train,'docs_extracted_features.pkl')
df_docs_extracted_features_train = pd.read_pickle(path_to_docs_extracted_features_train)
df_docs_extracted_features_train=df_docs_extracted_features_train.rename(columns={'features':'doc_embeddings'})

docs_extracted_features_test = docs_extracted_features_all[-number_of_test_docs:]
print(np.shape(docs_extracted_features_test))
# Out:
# (52, 27)

# %%
 dict_docs_extracted_features_test = {
    'text_names': df_preprocessed_texts_test.text_names,
    'labels' : df_preprocessed_texts_test.labels,
    'doc_embeddings' : docs_extracted_features_test
}
    

df_docs_extracted_features_test=pd.DataFrame(dict_docs_extracted_features_test)
df_docs_extracted_features_test
# Out:
#                                         doc_embeddings               labels  \
# 0    [-0.3852134346961975, -2.2532541751861572, -0....            apple_pie
# 4    [-0.26412728428840637, -0.7311620712280273, 0....            apple_pie
# 8    [-1.4469667673110962, -1.408789038658142, 0.21...            apple_pie
# 20   [0.019903600215911865, -0.3174292743206024, -0...           cheesecake
# 22   [-1.2963743209838867, 0.5744892954826355, -1.1...           cheesecake
# 28   [-1.652024745941162, -0.026261968538165092, 1....        chicken_curry
# 38   [0.23242518305778503, 1.2077902555465698, 1.74...        chicken_wings
# 39   [0.8355559706687927, 0.6210950613021851, 1.148...        chicken_wings
# 47   [1.0145593881607056, 1.3310211896896362, 0.903...        chicken_wings
# 54   [0.18747757375240326, 1.3766156435012817, 1.15...       chocolate_cake
# 60   [0.03196193277835846, 1.5395328998565674, -0.5...       chocolate_cake
# 67   [0.7191576361656189, -0.013874359428882599, -1...     chocolate_mousse
# 73   [0.4626045823097229, -0.27881553769111633, -1....         deviled_eggs
# 85   [-1.3555513620376587, -0.9855203032493591, 0.6...            dumplings
# 93   [1.7334016561508179, -1.564595103263855, 0.397...         french_toast
# 99   [1.0218563079833984, -0.7168242335319519, -0.6...         french_toast
# 105  [-1.1369421482086182, 0.10184969753026962, -0....           fried_rice
# 111  [-0.2931266129016876, 1.0448963642120361, 0.74...           fried_rice
# 123  [0.07735825330018997, 1.0864242315292358, -0.4...        frozen_yogurt
# 125  [0.62615567445755, 1.3037567138671875, -0.5927...        frozen_yogurt
# 133  [-1.1370608806610107, -0.17053739726543427, 0....         garlic_bread
# 138  [0.13554725050926208, -0.8430482149124146, 0.5...         garlic_bread
# 147  [-0.5402156114578247, -0.45338261127471924, -0...            hamburger
# 152  [1.8268173933029175, 0.2890753448009491, 2.096...               hummus
# 157  [-0.12386207282543182, -0.1511174738407135, 1....               hummus
# 163  [-1.028658390045166, 0.8057385683059692, 0.719...              lasagna
# 166  [-0.006298528518527746, -0.8249959349632263, -...              lasagna
# 172  [0.9204694628715515, 0.0468963123857975, 0.054...  macaroni_and_cheese
# 177  [0.7852831482887268, 0.5031698942184448, 0.245...  macaroni_and_cheese
# 182  [1.837973952293396, -1.00190007686615, 0.65404...  macaroni_and_cheese
# 190  [0.024162715300917625, -0.5185167789459229, -0...             macarons
# 197  [0.49031490087509155, 0.6697659492492676, 0.17...               nachos
# 202  [0.3459438979625702, 0.809394121170044, 0.2414...               nachos
# 210  [0.22043325006961823, 0.151164248585701, -1.35...          onion_rings
# 217  [1.2430874109268188, 0.5712745189666748, 0.829...             pancakes
# 229  [-1.2387635707855225, -2.1464691162109375, -0....                pizza
# 233  [-2.740250587463379, -0.8460986018180847, -1.8...              sashimi
# 239  [-0.011381002143025398, -1.9817516803741455, -...              sashimi
# 242  [-0.7761794924736023, -2.12882399559021, -1.01...                steak
# 244  [-1.449283480644226, -1.440066933631897, -0.65...                steak
# 246  [-0.6054810285568237, -0.23422029614448547, -0...                steak
# 256  [-2.083725929260254, -1.5103472471237183, -0.1...                steak
# 267  [0.578890860080719, -0.6994638442993164, -1.06...                sushi
# 274  [0.9757499098777771, -0.6145582795143127, -0.4...                sushi
# 277  [1.2032350301742554, -1.3484584093093872, -1.4...                sushi
# 284  [0.3061535358428955, -0.6598709225654602, -2.2...                sushi
# 287  [0.45055973529815674, 0.6639202237129211, 1.27...                tacos
# 293  [2.6401174068450928, 1.0233309268951416, -0.34...                tacos
# 302  [1.3395881652832031, 1.5968199968338013, -2.35...             tiramisu
# 303  [1.5414645671844482, 1.6234863996505737, -2.20...             tiramisu
# 313  [-1.9700900316238403, -1.1085718870162964, -1....              waffles
# 315  [0.2025827169418335, 0.47957831621170044, 0.06...              waffles
#
#     text_names
# 0        1.txt
# 4       13.txt
# 8        3.txt
# 20       4.txt
# 22       6.txt
# 28       3.txt
# 38      13.txt
# 39      14.txt
# 47       6.txt
# 54       3.txt
# 60       9.txt
# 67       7.txt
# 73       4.txt
# 85       7.txt
# 93      14.txt
# 99       7.txt
# 105     12.txt
# 111      5.txt
# 123      4.txt
# 125      6.txt
# 133      4.txt
# 138      9.txt
# 147      9.txt
# 152      2.txt
# 157      7.txt
# 163      2.txt
# 166      5.txt
# 172     10.txt
# 177     15.txt
# 182      6.txt
# 190      5.txt
# 197     12.txt
# 202      6.txt
# 210      5.txt
# 217      4.txt
# 229      7.txt
# 233      2.txt
# 239      8.txt
# 242     10.txt
# 244     12.txt
# 246     14.txt
# 256      3.txt
# 267     13.txt
# 274      2.txt
# 277     22.txt
# 284      8.txt
# 287     10.txt
# 293      7.txt
# 302      6.txt
# 303      7.txt
# 313      7.txt
# 315      9.txt

# %%
df_docs_extracted_features_all=pd.concat([df_docs_extracted_features_train,df_docs_extracted_features_test])
df_docs_extracted_features_all=df_docs_extracted_features_all.sort_index()
df_doc_embeddings=df_docs_extracted_features_all
df_doc_embeddings
# Out:
#                                         doc_embeddings         labels  \
# 0    [-0.3852134346961975, -2.2532541751861572, -0....      apple_pie
# 1    [-0.24955427646636963, -0.9826421737670898, 1....      apple_pie
# 2    [-0.3595167398452759, -1.917096495628357, 0.14...      apple_pie
# 3    [-1.8282828330993652, -1.1303541660308838, 0.2...      apple_pie
# 4    [-0.26412728428840637, -0.7311620712280273, 0....      apple_pie
# 5    [-0.266160786151886, -0.8897382616996765, -0.2...      apple_pie
# 6    [-0.6199544668197632, -2.098040819168091, 0.46...      apple_pie
# 7    [-0.9792886972427368, -1.758888840675354, 0.88...      apple_pie
# 8    [-1.4469667673110962, -1.408789038658142, 0.21...      apple_pie
# 9    [-1.346577525138855, -1.6965863704681396, 0.44...      apple_pie
# 10   [-0.40207439661026, -0.460137277841568, 0.1327...      apple_pie
# 11   [-0.7689167261123657, -0.6829455494880676, -0....      apple_pie
# 12   [-0.28463613986968994, -1.9537571668624878, -0...      apple_pie
# 13   [-0.08445477485656738, -1.5573848485946655, 0....      apple_pie
# 14   [-0.027063369750976562, -1.3993891477584839, 1...      apple_pie
# 15   [0.27984189987182617, 0.6530324816703796, -1.5...     cheesecake
# 16   [0.43558064103126526, 0.49440622329711914, -1....     cheesecake
# 17   [1.2922141551971436, -0.9313622713088989, -1.0...     cheesecake
# 18   [1.4885790348052979, 1.096511721611023, 0.2870...     cheesecake
# 19   [-0.09589019417762756, 0.8855007886886597, -0....     cheesecake
# 20   [0.019903600215911865, -0.3174292743206024, -0...     cheesecake
# 21   [0.8093789219856262, -0.7551910877227783, -1.2...     cheesecake
# 22   [-1.2963743209838867, 0.5744892954826355, -1.1...     cheesecake
# 23   [-1.3935028314590454, 1.2817113399505615, -0.6...     cheesecake
# 24   [-0.5860337615013123, -0.3248964250087738, -0....     cheesecake
# 25   [-1.407525658607483, -0.028818387538194656, -1...     cheesecake
# 26   [-0.8508996367454529, -0.7636610865592957, 0.5...  chicken_curry
# 27   [0.21264955401420593, -0.992591917514801, -0.9...  chicken_curry
# 28   [-1.652024745941162, -0.026261968538165092, 1....  chicken_curry
# 29   [-0.8686707615852356, -0.8378395438194275, 0.9...  chicken_curry
# ..                                                 ...            ...
# 286  [1.6704697608947754, 2.553302049636841, -2.481...          tacos
# 287  [0.45055973529815674, 0.6639202237129211, 1.27...          tacos
# 288  [-0.16742615401744843, 1.983201026916504, 0.84...          tacos
# 289  [0.3815311789512634, 2.0011582374572754, -0.54...          tacos
# 290  [1.2911945581436157, 2.0049774646759033, -1.13...          tacos
# 291  [1.2431716918945312, 0.5271018147468567, -0.59...          tacos
# 292  [-1.2440983057022095, 1.9036787748336792, -2.0...          tacos
# 293  [2.6401174068450928, 1.0233309268951416, -0.34...          tacos
# 294  [-0.7448776364326477, 1.6176127195358276, -0.0...          tacos
# 295  [0.004371568560600281, 1.332057237625122, 1.21...          tacos
# 296  [1.1422154903411865, 1.9577702283859253, -1.67...       tiramisu
# 297  [1.5070418119430542, 1.5975559949874878, -1.85...       tiramisu
# 298  [1.0471465587615967, 1.869505524635315, -2.043...       tiramisu
# 299  [-0.03557921200990677, 2.2737526893615723, -2....       tiramisu
# 300  [0.3640303909778595, 1.189726710319519, -0.874...       tiramisu
# 301  [-0.13649046421051025, 1.7855502367019653, -1....       tiramisu
# 302  [1.3395881652832031, 1.5968199968338013, -2.35...       tiramisu
# 303  [1.5414645671844482, 1.6234863996505737, -2.20...       tiramisu
# 304  [1.0407118797302246, 2.449871301651001, -0.714...       tiramisu
# 305  [1.1837632656097412, 0.31328344345092773, -3.1...       tiramisu
# 306  [-1.7231429815292358, 0.41761982440948486, -0....        waffles
# 307  [-0.3247416913509369, -0.7209973931312561, -0....        waffles
# 308  [0.02513846941292286, 0.033605534583330154, 0....        waffles
# 309  [0.9694137573242188, -1.0049406290054321, -0.8...        waffles
# 310  [1.0341912508010864, -0.0008001980022527277, 0...        waffles
# 311  [0.06142382696270943, -0.42245790362358093, -0...        waffles
# 312  [-1.646649718284607, -0.4515681862831116, 0.23...        waffles
# 313  [-1.9700900316238403, -1.1085718870162964, -1....        waffles
# 314  [-0.31929701566696167, 0.08910733461380005, 0....        waffles
# 315  [0.2025827169418335, 0.47957831621170044, 0.06...        waffles
#
#     text_names
# 0        1.txt
# 1       10.txt
# 2       11.txt
# 3       12.txt
# 4       13.txt
# 5       14.txt
# 6       15.txt
# 7        2.txt
# 8        3.txt
# 9        4.txt
# 10       5.txt
# 11       6.txt
# 12       7.txt
# 13       8.txt
# 14       9.txt
# 15       1.txt
# 16      10.txt
# 17      11.txt
# 18       2.txt
# 19       3.txt
# 20       4.txt
# 21       5.txt
# 22       6.txt
# 23       7.txt
# 24       8.txt
# 25       9.txt
# 26       1.txt
# 27       2.txt
# 28       3.txt
# 29       4.txt
# ..         ...
# 286      1.txt
# 287     10.txt
# 288      2.txt
# 289      3.txt
# 290      4.txt
# 291      5.txt
# 292      6.txt
# 293      7.txt
# 294      8.txt
# 295      9.txt
# 296      1.txt
# 297     10.txt
# 298      2.txt
# 299      3.txt
# 300      4.txt
# 301      5.txt
# 302      6.txt
# 303      7.txt
# 304      8.txt
# 305      9.txt
# 306      1.txt
# 307     10.txt
# 308      2.txt
# 309      3.txt
# 310      4.txt
# 311      5.txt
# 312      6.txt
# 313      7.txt
# 314      8.txt
# 315      9.txt
#
# [316 rows x 3 columns]

# %%
doc_embeddings=df_doc_embeddings.doc_embeddings.values.tolist()
labels=df_doc_embeddings.labels.values.tolist()
text_names=df_doc_embeddings.text_names.values.tolist()

unique_labels=sorted(set(labels))
number_of_recipe_categories=len(unique_labels)
possible_category_indices=np.linspace(0,number_of_recipe_categories-1,number_of_recipe_categories,dtype=int)
labels2integers=dict(zip(unique_labels,possible_category_indices))

print(labels2integers)

category_indices=[]
for l in labels:
    category_index=labels2integers[l]
    category_indices.append(category_index)
# Out:
# {'nachos': 17, 'deviled_eggs': 6, 'tiramisu': 25, 'pancakes': 19, 'dumplings': 7, 'chicken_curry': 2, 'garlic_bread': 11, 'hamburger': 12, 'sushi': 23, 'chicken_wings': 3, 'chocolate_cake': 4, 'fried_rice': 9, 'sashimi': 21, 'onion_rings': 18, 'macarons': 16, 'apple_pie': 0, 'cheesecake': 1, 'lasagna': 14, 'steak': 22, 'tacos': 24, 'french_toast': 8, 'frozen_yogurt': 10, 'macaroni_and_cheese': 15, 'chocolate_mousse': 5, 'waffles': 26, 'hummus': 13, 'pizza': 20}

# %%
#PCA

pca = PCA(n_components=2)
pca_2D_embeddings = pca.fit_transform(doc_embeddings)

dict_PCA_2D = {
    'pca-1' : pca_2D_embeddings[:,0],
    'pca-2' : pca_2D_embeddings[:,1],
    'labels' : labels,
    'category_indices': category_indices,
    'text_names': text_names
}

df_PCA_2D=pd.DataFrame(dict_PCA_2D)

# %%
traces=[]

for n in range(0,number_of_recipe_categories):
    df_category=df_PCA_2D[(df_PCA_2D.category_indices==n)]
    point_name=str(df_category.labels[df_category.index[0]])
    trace = go.Scatter(
    x=df_category['pca-1'],
    y=df_category['pca-2'],
    mode='markers',
    marker=dict(
        colorscale='Viridis',
        opacity=0.7,
        line=dict(color='rgb(140, 140, 170)')
    ),
    name=point_name,
    text=df_category['text_names'],
    )

    traces.append(trace)

layout = go.Layout(
    title='PCA reduction: 2D features',
    hovermode='closest',
    margin=dict(
       l=30,
       r=30,
       b=30,
       t=30
    ),
      scene = dict(
        xaxis = dict(
            title='pca-1',
       ),
       yaxis = dict(
           title='pca-2',
       ),
    ),
 
)

fig = go.Figure(data=traces, layout=layout)
iplot(fig)


print("test recipes")
df_preprocessed_texts_test
# Out:
# <div id="185c491e-adfd-4096-8809-94feb39dcab1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("185c491e-adfd-4096-8809-94feb39dcab1", [{"uid": "bf1747c5-a89a-4278-af96-36e1683b06e1", "name": "apple_pie", "marker": {"opacity": 0.7, "colorscale": "Viridis", "line": {"color": "rgb(140, 140, 170)"}}, "y": [1.1108110872446726, -0.5108017061332943, 1.2166300601783588, -0.5998746901087215, 0.7532585814894385, 1.274274802838298, 0.2903551869010173, 0.5941893098266315, -0.2574968976087946, 0.3500331530783275, -0.710455120800677, 0.1430133996985353, 0.520415776929197, -0.132130577990521, 0.567012246144676], "text": ["1.txt", "10.txt", "11.txt", "12.txt", "13.txt", "14.txt", "15.txt", "2.txt", "3.txt", "4.txt", "5.txt", "6.txt", "7.txt", "8.txt", "9.txt"], "mode": "markers", "type": "scatter", "x": [1.8783656013809726, 1.0962362524400193, 0.7595828184182245, 1.3021026267725235, 1.472518943306675, 1.5061745611992097, 0.6712107145568595, 2.5059792728925365, 1.7390150576105359, 1.1889801424571003, 1.546919337872008, 0.5974966174389046, 0.5583148300525659, 0.7395796019567579, 0.49971081119758043]}, {"uid": "fcd6b620-f971-4074-9a2c-8e54eda2b7c7", "name": "cheesecake", "marker": {"opacity": 0.7, "colorscale": "Viridis", "line": {"color": "rgb(140, 140, 170)"}}, "y": [0.7925202843772287, -0.002375886545075187, 0.860136644032078, -0.5781269464657595, 0.5383188971843839, 1.0613367996960628, 0.7535202946186066, 1.509865713772806, 0.5764377182732501, 1.0083042721414548, 1.4735396124647382], "text": ["1.txt", "10.txt", "11.txt", "2.txt", "3.txt", "4.txt", "5.txt", "6.txt", "7.txt", "8.txt", "9.txt"], "mode": "markers", "type": "scatter", "x": [1.4670612139397647, 1.1125145307804363, 1.3386450105765255, 2.8315284776169953, 1.9482591326191523, 2.165345207283038, 2.7863463933873382, 2.155601610472504, 1.5228917749437552, 2.382530770778786, 2.5468918597798242]}, {"uid": "0ac84b86-aa62-48c5-882f-ff722691865d", "name": "chicken_curry", "marker": {"opacity": 0.7, "colorscale": "Viridis", "line": {"color": "rgb(140, 140, 170)"}}, "y": [-0.6520445178595914, -0.41402026125904046, -1.3718064337168716, -0.673779501740404, 0.03572971694970275, -0.3744201650512049, -0.14757817205081597, -1.1573270260497415], "text": ["1.txt", "2.txt", "3.txt", "4.txt", "5.txt", "6.txt", "7.txt", "8.txt"], "mode": "markers", "type": "scatter", "x": [-2.4674493435020564, -2.2759578864155596, -1.8405260945133421, -2.798579278070862, -2.3224084589362564, -1.9641535045493375, -1.6970610987229306, -2.273924926266288]}, {"uid": "8ddb78b5-9481-402e-b3ae-68276053e340", "name": "chicken_wings", "marker": {"opacity": 0.7, "colorscale": "Viridis", "line": {"color": "rgb(140, 140, 170)"}}, "y": [-2.050951315359917, -1.6955610205630096, -0.6519104700239323, -1.4219763788698376, -1.5030779163341765, -0.9336536618093302, -0.6776412208599768, -0.3524748248215323, -1.7094077330007011, -1.8606867427616978, -1.8086676751143893, -1.3153785627094876, -0.7378151157597055, -1.8596946307120452, -1.1027258051261364, -1.4687502568910804, -1.209567721813045], "text": ["1.txt", "10.txt", "11.txt", "12.txt", "13.txt", "14.txt", "15.txt", "16.txt", "17.txt", "2.txt", "3.txt", "4.txt", "5.txt", "6.txt", "7.txt", "8.txt", "9.txt"], "mode": "markers", "type": "scatter", "x": [-0.35845588847947196, -0.9941173434675603, -0.45865254673347877, -0.9157416320289716, -0.5019764411090283, -1.0756103071540415, -0.8228740541809229, -0.9729774527749927, -1.1690648198521731, -0.9885620758000471, -0.9528962473898336, -1.5870180465972896, -0.4884769850889692, -1.4457483999897172, -1.3443025941974507, -1.225720132761261, -0.9479191704188451]}, {"uid": "ca71205e-af2a-4778-a219-f9a0d4ff7cbd", "name": "chocolate_cake", "marker": {"opacity": 0.7, "colorscale": "Viridis", "line": {"color": "rgb(140, 140, 170)"}}, "y": [0.7843185891017498, -0.49852 ...
# test recipes
#                   labels  number_of_important_words  \
# 0              apple_pie                         58
# 4              apple_pie                         28
# 8              apple_pie                         69
# 20            cheesecake                         44
# 22            cheesecake                         32
# 28         chicken_curry                         72
# 38         chicken_wings                         40
# 39         chicken_wings                         63
# 47         chicken_wings                         35
# 54        chocolate_cake                         31
# 60        chocolate_cake                         91
# 67      chocolate_mousse                         24
# 73          deviled_eggs                         41
# 85             dumplings                        108
# 93          french_toast                         37
# 99          french_toast                         47
# 105           fried_rice                         48
# 111           fried_rice                         35
# 123        frozen_yogurt                         15
# 125        frozen_yogurt                         18
# 133         garlic_bread                         79
# 138         garlic_bread                         58
# 147            hamburger                        109
# 152               hummus                         52
# 157               hummus                         30
# 163              lasagna                         63
# 166              lasagna                         71
# 172  macaroni_and_cheese                         37
# 177  macaroni_and_cheese                         46
# 182  macaroni_and_cheese                         53
# 190             macarons                         71
# 197               nachos                         54
# 202               nachos                         76
# 210          onion_rings                         50
# 217             pancakes                         27
# 229                pizza                        108
# 233              sashimi                         56
# 239              sashimi                         57
# 242                steak                         28
# 244                steak                         33
# 246                steak                         51
# 256                steak                         27
# 267                sushi                        158
# 274                sushi                         86
# 277                sushi                         61
# 284                sushi                         98
# 287                tacos                         35
# 293                tacos                         24
# 302             tiramisu                         22
# 303             tiramisu                         46
# 313              waffles                         30
# 315              waffles                         27
#
#                                     preprocessed_texts text_names
# 0    [apple, pie, recipe, dessert, cinnamon, roll, ...      1.txt
# 4    [cooker, apple, recipe, dessert, apple, pie, f...     13.txt
# 8    [apple, pie, recipe, bakery, pie, crust, cream...      3.txt
# 20   [chocolate, recipe, dessert, brownie, mix, cre...      4.txt
# 22   [mini, cheesecake, dessert, cream, cheese, cre...      6.txt
# 28   [coconut, chicken, curry, recipe, chicken, oni...      3.txt
# 38   [root, beer, wing, recipe, appetizer, chicken,...     13.txt
# 39   [mango, chicken, wing, recipe, appetizer, flou...     14.txt
# 47   [chicken, wing, recipe, appetizer, chicken, wi...      6.txt
# 54   [chocolate, recipe, chocolate, cake, mix, milk...      3.txt
# 60   [bake, chocolate, cake, recipe, dessert, choco...      9.txt
# 67   [strawberry, chocolate, mousse, recipe, desser...      7.txt
# 73   [egg, recipe, appetizer, egg, salt, pepper, to...      4.txt
# 85   [dumpling, water, gelatin, powder, soy, sauce,...      7.txt
# 93   [toast, recipe, breakfast, egg, milk, syrup, v...     14.txt
# 99   [toast, recipe, breakfast, egg, cream, sugar, ...      7.txt
# 105  [potato, rice, recipe, potato, oil, onion, car...     12.txt
# 111  [chicken, rice, recipe, chicken, rice, recipe,...      5.txt
# 123  [strawberry, yogurt, recipe, snack, strawberry...      4.txt
# 125  [strawberry, banana, yogurt, recipe, snack, st...      6.txt
# 133  [chicken, bread, recipe, appetizer, chicken, f...      4.txt
# 138  [steak, stuffed, bread, recipe, appetizer, oil...      9.txt
# 147  [burger, recipe, dinner, chickpea, onion, pars...      9.txt
# 152  [beet, hummus, recipe, snack, garbanzo, bean, ...      2.txt
# 157  [hummus, carrot, snack, chickpea, oil, lemon, ...      7.txt
# 163  [chicken, lasagna, recipe, dinner, salt, peppe...      2.txt
# 166  [lasagne, roll, dinner, beef, onion, tomato, o...      5.txt
# 172  [mac, amp, recipe, macaroni, cream, cheese, ch...     10.txt
# 177  [mac, recipe, potato, carrot, onion, cashew, p...     15.txt
# 182  [cheese, mac, recipe, macaroni, milk, egg, but...      6.txt
# 190  [macarons, bakery, almond, meal, sugar, egg, s...      5.txt
# 197  [steak, nacho, recipe, appetizer, steak, salt,...     12.txt
# 202  [mustard, chicken, tater, tot, recipe, appetiz...      6.txt
# 210  [onion, ring, recipe, salt, powder, onion, flo...      5.txt
# 217  [blueberry, pancake, breakfast, banana, oat, e...      4.txt
# 229  [pizza, recipe, dinner, water, sugar, yeast, f...      7.txt
# 233  [sashimi, salmon, filet, sesame, seed, oil, se...      2.txt
# 239  [tuna, piece, piece, ginger, soy, sauce, sauce...      8.txt
# 242  [onion, clove, oil, vinegar, soy, sauce, musta...     10.txt
# 244  [recipe, dinner, sirloin, steak, kosher, salt,...     12.txt
# 246  [pepper, steak, recipe, dinner, strip, steak, ...     14.txt
# 256  [clove, ginger, onion, soy, sauce, oil, meat, ...      3.txt
# 267  [breast, sesame, oil, oil, sea, salt, teriyaki...     13.txt
# 274  [rice, water, piece, rice, vinegar, sugar, sal...      2.txt
# 277  [spicy, tuna, roll, recipe, dinner, sushi, ric...     22.txt
# 284  [avocado, nori, season, rice, rice, recipe, to...      8.txt
# 287  [bean, potato, taco, recipe, lunch, potato, oi...     10.txt
# 293  [chicken, taco, recipe, tortilla, butter, chic...      7.txt
# 302  [egg, yolk, sugar, mascarpone, ladyfinger, cof...      6.txt
# 303  [strawberry, confectioner, sugar, mascarpone, ...      7.txt
# 313  [pizza, waffle, pizza, dough, marinara, sauce,...      7.txt
# 315  [waffle, recipe, mix, egg, oil, milk, egg, oil...      9.txt

# %%
#t-SNE 2D
    
tsne2D = TSNE(perplexity=15, n_components=2, verbose=2, init='pca', n_iter=2000,
                  n_iter_without_progress=500, learning_rate=5,method='exact')
tsne_2D_embeddings = tsne2D.fit_transform(doc_embeddings)
    
dict_TSNE_2D = {
    'pca-1' : tsne_2D_embeddings[:,0],
    'pca-2' : tsne_2D_embeddings[:,1],
    'labels' : labels,
    'category_indices': category_indices,
    'text_names': text_names
}

df_TSNE_2D=pd.DataFrame(dict_TSNE_2D)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 316 / 316
# [t-SNE] Mean sigma: 2.207332
# [t-SNE] Iteration 50: error = 64.9495695, gradient norm = 0.0029804 (50 iterations in 0.361s)
# [t-SNE] Iteration 100: error = 64.9601452, gradient norm = 0.0000106 (50 iterations in 0.303s)
# [t-SNE] Iteration 150: error = 64.9601453, gradient norm = 0.0000000 (50 iterations in 0.285s)
# [t-SNE] Iteration 150: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 150 iterations with early exaggeration: 64.960145
# [t-SNE] Iteration 200: error = 1.8474220, gradient norm = 0.0154494 (50 iterations in 0.295s)
# [t-SNE] Iteration 250: error = 0.8280275, gradient norm = 0.0041434 (50 iterations in 0.303s)
# [t-SNE] Iteration 300: error = 0.6844100, gradient norm = 0.0017247 (50 iterations in 0.298s)
# [t-SNE] Iteration 350: error = 0.6225371, gradient norm = 0.0010062 (50 iterations in 0.300s)
# [t-SNE] Iteration 400: error = 0.5916056, gradient norm = 0.0006679 (50 iterations in 0.298s)
# [t-SNE] Iteration 450: error = 0.5725566, gradient norm = 0.0004708 (50 iterations in 0.295s)
# [t-SNE] Iteration 500: error = 0.5611139, gradient norm = 0.0003627 (50 iterations in 0.288s)
# [t-SNE] Iteration 550: error = 0.5534384, gradient norm = 0.0002623 (50 iterations in 0.294s)
# [t-SNE] Iteration 600: error = 0.5481584, gradient norm = 0.0002055 (50 iterations in 0.294s)
# [t-SNE] Iteration 650: error = 0.5443239, gradient norm = 0.0001668 (50 iterations in 0.299s)
# [t-SNE] Iteration 700: error = 0.5414411, gradient norm = 0.0001386 (50 iterations in 0.297s)
# [t-SNE] Iteration 750: error = 0.5392085, gradient norm = 0.0001175 (50 iterations in 0.298s)
# [t-SNE] Iteration 800: error = 0.5374356, gradient norm = 0.0001011 (50 iterations in 0.296s)
# [t-SNE] Iteration 850: error = 0.5359996, gradient norm = 0.0000885 (50 iterations in 0.295s)
# [t-SNE] Iteration 900: error = 0.5348200, gradient norm = 0.0000781 (50 iterations in 0.295s)
# [t-SNE] Iteration 950: error = 0.5338323, gradient norm = 0.0000709 (50 iterations in 0.309s)
# [t-SNE] Iteration 1000: error = 0.5329870, gradient norm = 0.0000655 (50 iterations in 0.296s)
# [t-SNE] Iteration 1050: error = 0.5322392, gradient norm = 0.0000606 (50 iterations in 0.305s)
# [t-SNE] Iteration 1100: error = 0.5315821, gradient norm = 0.0000568 (50 iterations in 0.309s)
# [t-SNE] Iteration 1150: error = 0.5310133, gradient norm = 0.0000519 (50 iterations in 0.285s)
# [t-SNE] Iteration 1200: error = 0.5305245, gradient norm = 0.0000479 (50 iterations in 0.303s)
# [t-SNE] Iteration 1250: error = 0.5301070, gradient norm = 0.0000434 (50 iterations in 0.308s)
# [t-SNE] Iteration 1300: error = 0.5297388, gradient norm = 0.0000402 (50 iterations in 0.306s)
# [t-SNE] Iteration 1350: error = 0.5294137, gradient norm = 0.0000381 (50 iterations in 0.297s)
# [t-SNE] Iteration 1400: error = 0.5291241, gradient norm = 0.0000358 (50 iterations in 0.297s)
# [t-SNE] Iteration 1450: error = 0.5288601, gradient norm = 0.0000340 (50 iterations in 0.302s)
# [t-SNE] Iteration 1500: error = 0.5286197, gradient norm = 0.0000330 (50 iterations in 0.292s)
# [t-SNE] Iteration 1550: error = 0.5284018, gradient norm = 0.0000315 (50 iterations in 0.298s)
# [t-SNE] Iteration 1600: error = 0.5281976, gradient norm = 0.0000302 (50 iterations in 0.294s)
# [t-SNE] Iteration 1650: error = 0.5280064, gradient norm = 0.0000300 (50 iterations in 0.317s)
# [t-SNE] Iteration 1700: error = 0.5278188, gradient norm = 0.0000309 (50 iterations in 0.309s)
# [t-SNE] Iteration 1750: error = 0.5274941, gradient norm = 0.0000933 (50 iterations in 0.299s)
# [t-SNE] Iteration 1800: error = 0.5269822, gradient norm = 0.0000471 (50 iterations in 0.291s)
# [t-SNE] Iteration 1850: error = 0.5268279, gradient norm = 0.0000424 (50 iterations in 0.297s)
# [t-SNE] Iteration 1900: error = 0.5266758, gradient norm = 0.0000386 (50 iterations in 0.296s)
# [t-SNE] Iteration 1950: error = 0.5265322, gradient norm = 0.0000341 (50 iterations in 0.304s)
# [t-SNE] Iteration 2000: error = 0.5264023, gradient norm = 0.0000302 (50 iterations in 0.303s)
# [t-SNE] KL divergence after 2000 iterations: 0.526402

# %%
traces=[]

for n in range(0,number_of_recipe_categories):
    df_category=df_TSNE_2D[(df_TSNE_2D.category_indices==n)]
    point_name=str(df_category.labels[df_category.index[0]])
    trace = go.Scatter(
    x=df_category['pca-1'],
    y=df_category['pca-2'],
    mode='markers',
    marker=dict(
        colorscale='Viridis',
        opacity=0.7,
        line=dict(color='rgb(140, 140, 170)')
    ),
    name=point_name,
    text=df_category['text_names'],
    )

    traces.append(trace)

layout = go.Layout(
    title='t-SNE reduction: 2D features',
    hovermode='closest',
    margin=dict(
       l=30,
       r=30,
       b=30,
       t=30
    ),
      scene = dict(
        xaxis = dict(
            title='pca-1',
       ),
       yaxis = dict(
           title='pca-2',
       ),
    ),
 
)

fig = go.Figure(data=traces, layout=layout)
iplot(fig)

print("test recipes")
df_preprocessed_texts_test
# Out:
# <div id="3a9d19c1-6dcc-4ed6-9d48-e99168242997" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3a9d19c1-6dcc-4ed6-9d48-e99168242997", [{"uid": "64f4e95c-051f-4979-b60d-83c73114170a", "name": "apple_pie", "marker": {"opacity": 0.7, "colorscale": "Viridis", "line": {"color": "rgb(140, 140, 170)"}}, "y": [8.67186164855957, 9.32677173614502, 9.818746566772461, 5.193210124969482, -0.6532114148139954, -0.3738202750682831, 5.301228046417236, 7.844295024871826, 5.2821855545043945, 6.637635707855225, 2.828120470046997, 3.192281484603882, 7.741203784942627, 7.6761064529418945, 3.7901086807250977], "text": ["1.txt", "10.txt", "11.txt", "12.txt", "13.txt", "14.txt", "15.txt", "2.txt", "3.txt", "4.txt", "5.txt", "6.txt", "7.txt", "8.txt", "9.txt"], "mode": "markers", "type": "scatter", "x": [29.681894302368164, 23.934064865112305, 22.237648010253906, 26.708053588867188, 34.767066955566406, 34.02805709838867, 24.00213050842285, 30.66762924194336, 27.862138748168945, 24.574464797973633, 28.663434982299805, 26.386938095092773, 21.932096481323242, 26.465585708618164, 22.93423843383789]}, {"uid": "899f0067-43a5-47c6-916b-2ddc0b5ec01e", "name": "cheesecake", "marker": {"opacity": 0.7, "colorscale": "Viridis", "line": {"color": "rgb(140, 140, 170)"}}, "y": [-10.119699478149414, -8.68684196472168, -1.8329919576644897, -2.3175222873687744, -6.70974063873291, -1.1453958749771118, 0.9394406080245972, -9.76340103149414, -10.277165412902832, -8.866971015930176, 1.1017439365386963], "text": ["1.txt", "10.txt", "11.txt", "2.txt", "3.txt", "4.txt", "5.txt", "6.txt", "7.txt", "8.txt", "9.txt"], "mode": "markers", "type": "scatter", "x": [32.68410873413086, 32.56488800048828, 41.488990783691406, 43.92365646362305, 34.07089614868164, 42.575340270996094, 45.16038131713867, 29.11812973022461, 30.557926177978516, 28.27537727355957, 42.26755905151367]}, {"uid": "6b5cca56-8efc-445e-bf7c-86874e3ffe7c", "name": "chicken_curry", "marker": {"opacity": 0.7, "colorscale": "Viridis", "line": {"color": "rgb(140, 140, 170)"}}, "y": [-22.2133846282959, -19.097970962524414, -20.769493103027344, -22.73797607421875, -17.86885643005371, -19.648130416870117, -18.723487854003906, -19.89920425415039], "text": ["1.txt", "2.txt", "3.txt", "4.txt", "5.txt", "6.txt", "7.txt", "8.txt"], "mode": "markers", "type": "scatter", "x": [-28.5023193359375, -35.78425216674805, -31.451412200927734, -29.489376068115234, -30.8516902923584, -34.180171966552734, -28.859622955322266, -30.74624252319336]}, {"uid": "7c38c2dd-a0a1-4560-a4a9-9b6ff0908965", "name": "chicken_wings", "marker": {"opacity": 0.7, "colorscale": "Viridis", "line": {"color": "rgb(140, 140, 170)"}}, "y": [-40.934898376464844, -32.42249298095703, -35.28176498413086, -39.87451171875, -33.186824798583984, -32.51355743408203, -35.51240539550781, -39.1662483215332, -35.07594299316406, -42.28750228881836, -40.06671905517578, -33.47630310058594, -39.243125915527344, -33.269691467285156, -38.127159118652344, -41.16778564453125, -33.62847900390625], "text": ["1.txt", "10.txt", "11.txt", "12.txt", "13.txt", "14.txt", "15.txt", "16.txt", "17.txt", "2.txt", "3.txt", "4.txt", "5.txt", "6.txt", "7.txt", "8.txt", "9.txt"], "mode": "markers", "type": "scatter", "x": [2.641190767288208, 4.75935697555542, 1.5160022974014282, 7.080928325653076, 7.68814754486084, 2.7871201038360596, -0.32888633012771606, 5.0874128341674805, 4.254090785980225, 3.656665802001953, 0.9933323860168457, -1.1902740001678467, 2.5327975749969482, 1.2731640338897705, 7.422269821166992, 6.826568126678467, 5.246579170227051]}, {"uid": "0ef872f3-ab41-4915-b6c4-5549a9c5a21d", "name": "chocolate_cake", "marker": {"opacity": 0.7, "colorscale": "Viridis", "line": {"color": "rgb(140, 140, 170)"}}, "y": [-14.207756042480469, -15.825533866882324, -10.463199615478516, -11.572075843811035, -13.04009246 ...
# test recipes
#                   labels  number_of_important_words  \
# 0              apple_pie                         58
# 4              apple_pie                         28
# 8              apple_pie                         69
# 20            cheesecake                         44
# 22            cheesecake                         32
# 28         chicken_curry                         72
# 38         chicken_wings                         40
# 39         chicken_wings                         63
# 47         chicken_wings                         35
# 54        chocolate_cake                         31
# 60        chocolate_cake                         91
# 67      chocolate_mousse                         24
# 73          deviled_eggs                         41
# 85             dumplings                        108
# 93          french_toast                         37
# 99          french_toast                         47
# 105           fried_rice                         48
# 111           fried_rice                         35
# 123        frozen_yogurt                         15
# 125        frozen_yogurt                         18
# 133         garlic_bread                         79
# 138         garlic_bread                         58
# 147            hamburger                        109
# 152               hummus                         52
# 157               hummus                         30
# 163              lasagna                         63
# 166              lasagna                         71
# 172  macaroni_and_cheese                         37
# 177  macaroni_and_cheese                         46
# 182  macaroni_and_cheese                         53
# 190             macarons                         71
# 197               nachos                         54
# 202               nachos                         76
# 210          onion_rings                         50
# 217             pancakes                         27
# 229                pizza                        108
# 233              sashimi                         56
# 239              sashimi                         57
# 242                steak                         28
# 244                steak                         33
# 246                steak                         51
# 256                steak                         27
# 267                sushi                        158
# 274                sushi                         86
# 277                sushi                         61
# 284                sushi                         98
# 287                tacos                         35
# 293                tacos                         24
# 302             tiramisu                         22
# 303             tiramisu                         46
# 313              waffles                         30
# 315              waffles                         27
#
#                                     preprocessed_texts text_names
# 0    [apple, pie, recipe, dessert, cinnamon, roll, ...      1.txt
# 4    [cooker, apple, recipe, dessert, apple, pie, f...     13.txt
# 8    [apple, pie, recipe, bakery, pie, crust, cream...      3.txt
# 20   [chocolate, recipe, dessert, brownie, mix, cre...      4.txt
# 22   [mini, cheesecake, dessert, cream, cheese, cre...      6.txt
# 28   [coconut, chicken, curry, recipe, chicken, oni...      3.txt
# 38   [root, beer, wing, recipe, appetizer, chicken,...     13.txt
# 39   [mango, chicken, wing, recipe, appetizer, flou...     14.txt
# 47   [chicken, wing, recipe, appetizer, chicken, wi...      6.txt
# 54   [chocolate, recipe, chocolate, cake, mix, milk...      3.txt
# 60   [bake, chocolate, cake, recipe, dessert, choco...      9.txt
# 67   [strawberry, chocolate, mousse, recipe, desser...      7.txt
# 73   [egg, recipe, appetizer, egg, salt, pepper, to...      4.txt
# 85   [dumpling, water, gelatin, powder, soy, sauce,...      7.txt
# 93   [toast, recipe, breakfast, egg, milk, syrup, v...     14.txt
# 99   [toast, recipe, breakfast, egg, cream, sugar, ...      7.txt
# 105  [potato, rice, recipe, potato, oil, onion, car...     12.txt
# 111  [chicken, rice, recipe, chicken, rice, recipe,...      5.txt
# 123  [strawberry, yogurt, recipe, snack, strawberry...      4.txt
# 125  [strawberry, banana, yogurt, recipe, snack, st...      6.txt
# 133  [chicken, bread, recipe, appetizer, chicken, f...      4.txt
# 138  [steak, stuffed, bread, recipe, appetizer, oil...      9.txt
# 147  [burger, recipe, dinner, chickpea, onion, pars...      9.txt
# 152  [beet, hummus, recipe, snack, garbanzo, bean, ...      2.txt
# 157  [hummus, carrot, snack, chickpea, oil, lemon, ...      7.txt
# 163  [chicken, lasagna, recipe, dinner, salt, peppe...      2.txt
# 166  [lasagne, roll, dinner, beef, onion, tomato, o...      5.txt
# 172  [mac, amp, recipe, macaroni, cream, cheese, ch...     10.txt
# 177  [mac, recipe, potato, carrot, onion, cashew, p...     15.txt
# 182  [cheese, mac, recipe, macaroni, milk, egg, but...      6.txt
# 190  [macarons, bakery, almond, meal, sugar, egg, s...      5.txt
# 197  [steak, nacho, recipe, appetizer, steak, salt,...     12.txt
# 202  [mustard, chicken, tater, tot, recipe, appetiz...      6.txt
# 210  [onion, ring, recipe, salt, powder, onion, flo...      5.txt
# 217  [blueberry, pancake, breakfast, banana, oat, e...      4.txt
# 229  [pizza, recipe, dinner, water, sugar, yeast, f...      7.txt
# 233  [sashimi, salmon, filet, sesame, seed, oil, se...      2.txt
# 239  [tuna, piece, piece, ginger, soy, sauce, sauce...      8.txt
# 242  [onion, clove, oil, vinegar, soy, sauce, musta...     10.txt
# 244  [recipe, dinner, sirloin, steak, kosher, salt,...     12.txt
# 246  [pepper, steak, recipe, dinner, strip, steak, ...     14.txt
# 256  [clove, ginger, onion, soy, sauce, oil, meat, ...      3.txt
# 267  [breast, sesame, oil, oil, sea, salt, teriyaki...     13.txt
# 274  [rice, water, piece, rice, vinegar, sugar, sal...      2.txt
# 277  [spicy, tuna, roll, recipe, dinner, sushi, ric...     22.txt
# 284  [avocado, nori, season, rice, rice, recipe, to...      8.txt
# 287  [bean, potato, taco, recipe, lunch, potato, oi...     10.txt
# 293  [chicken, taco, recipe, tortilla, butter, chic...      7.txt
# 302  [egg, yolk, sugar, mascarpone, ladyfinger, cof...      6.txt
# 303  [strawberry, confectioner, sugar, mascarpone, ...      7.txt
# 313  [pizza, waffle, pizza, dough, marinara, sauce,...      7.txt
# 315  [waffle, recipe, mix, egg, oil, milk, egg, oil...      9.txt

# %%
print("Saving extracted features from test dataset pandas dataframe to: ", path_to_save_docs_embeddings_pkl)
df_docs_extracted_features_test.to_pickle(path_to_save_docs_embeddings_pkl)

path_to_save_train_test_docs_extracted_features=os.path.join(cwd,os.pardir,'multimodal_classification','data','docs_extracted_features.pkl')
print("Saving extracted features from train and from test dataset pandas dataframe to: ", path_to_save_train_test_docs_extracted_features)
df_doc_embeddings.to_pickle(path_to_save_train_test_docs_extracted_features)

print("Extracted features from train and from test dataset pandas dataframe:")
df_doc_embeddings
# Out:
# Saving extracted features from test dataset pandas dataframe to:  /notebooks/school/text_feature_extraction/models/test/10/docs_extracted_features.pkl
# Saving extracted features from train and from test dataset pandas dataframe to:  /notebooks/school/text_feature_extraction/../multimodal_classification/data/docs_extracted_features.pkl
# Extracted features from train and from test dataset pandas dataframe:
#                                         doc_embeddings         labels  \
# 0    [-0.3852134346961975, -2.2532541751861572, -0....      apple_pie
# 1    [-0.24955427646636963, -0.9826421737670898, 1....      apple_pie
# 2    [-0.3595167398452759, -1.917096495628357, 0.14...      apple_pie
# 3    [-1.8282828330993652, -1.1303541660308838, 0.2...      apple_pie
# 4    [-0.26412728428840637, -0.7311620712280273, 0....      apple_pie
# 5    [-0.266160786151886, -0.8897382616996765, -0.2...      apple_pie
# 6    [-0.6199544668197632, -2.098040819168091, 0.46...      apple_pie
# 7    [-0.9792886972427368, -1.758888840675354, 0.88...      apple_pie
# 8    [-1.4469667673110962, -1.408789038658142, 0.21...      apple_pie
# 9    [-1.346577525138855, -1.6965863704681396, 0.44...      apple_pie
# 10   [-0.40207439661026, -0.460137277841568, 0.1327...      apple_pie
# 11   [-0.7689167261123657, -0.6829455494880676, -0....      apple_pie
# 12   [-0.28463613986968994, -1.9537571668624878, -0...      apple_pie
# 13   [-0.08445477485656738, -1.5573848485946655, 0....      apple_pie
# 14   [-0.027063369750976562, -1.3993891477584839, 1...      apple_pie
# 15   [0.27984189987182617, 0.6530324816703796, -1.5...     cheesecake
# 16   [0.43558064103126526, 0.49440622329711914, -1....     cheesecake
# 17   [1.2922141551971436, -0.9313622713088989, -1.0...     cheesecake
# 18   [1.4885790348052979, 1.096511721611023, 0.2870...     cheesecake
# 19   [-0.09589019417762756, 0.8855007886886597, -0....     cheesecake
# 20   [0.019903600215911865, -0.3174292743206024, -0...     cheesecake
# 21   [0.8093789219856262, -0.7551910877227783, -1.2...     cheesecake
# 22   [-1.2963743209838867, 0.5744892954826355, -1.1...     cheesecake
# 23   [-1.3935028314590454, 1.2817113399505615, -0.6...     cheesecake
# 24   [-0.5860337615013123, -0.3248964250087738, -0....     cheesecake
# 25   [-1.407525658607483, -0.028818387538194656, -1...     cheesecake
# 26   [-0.8508996367454529, -0.7636610865592957, 0.5...  chicken_curry
# 27   [0.21264955401420593, -0.992591917514801, -0.9...  chicken_curry
# 28   [-1.652024745941162, -0.026261968538165092, 1....  chicken_curry
# 29   [-0.8686707615852356, -0.8378395438194275, 0.9...  chicken_curry
# ..                                                 ...            ...
# 286  [1.6704697608947754, 2.553302049636841, -2.481...          tacos
# 287  [0.45055973529815674, 0.6639202237129211, 1.27...          tacos
# 288  [-0.16742615401744843, 1.983201026916504, 0.84...          tacos
# 289  [0.3815311789512634, 2.0011582374572754, -0.54...          tacos
# 290  [1.2911945581436157, 2.0049774646759033, -1.13...          tacos
# 291  [1.2431716918945312, 0.5271018147468567, -0.59...          tacos
# 292  [-1.2440983057022095, 1.9036787748336792, -2.0...          tacos
# 293  [2.6401174068450928, 1.0233309268951416, -0.34...          tacos
# 294  [-0.7448776364326477, 1.6176127195358276, -0.0...          tacos
# 295  [0.004371568560600281, 1.332057237625122, 1.21...          tacos
# 296  [1.1422154903411865, 1.9577702283859253, -1.67...       tiramisu
# 297  [1.5070418119430542, 1.5975559949874878, -1.85...       tiramisu
# 298  [1.0471465587615967, 1.869505524635315, -2.043...       tiramisu
# 299  [-0.03557921200990677, 2.2737526893615723, -2....       tiramisu
# 300  [0.3640303909778595, 1.189726710319519, -0.874...       tiramisu
# 301  [-0.13649046421051025, 1.7855502367019653, -1....       tiramisu
# 302  [1.3395881652832031, 1.5968199968338013, -2.35...       tiramisu
# 303  [1.5414645671844482, 1.6234863996505737, -2.20...       tiramisu
# 304  [1.0407118797302246, 2.449871301651001, -0.714...       tiramisu
# 305  [1.1837632656097412, 0.31328344345092773, -3.1...       tiramisu
# 306  [-1.7231429815292358, 0.41761982440948486, -0....        waffles
# 307  [-0.3247416913509369, -0.7209973931312561, -0....        waffles
# 308  [0.02513846941292286, 0.033605534583330154, 0....        waffles
# 309  [0.9694137573242188, -1.0049406290054321, -0.8...        waffles
# 310  [1.0341912508010864, -0.0008001980022527277, 0...        waffles
# 311  [0.06142382696270943, -0.42245790362358093, -0...        waffles
# 312  [-1.646649718284607, -0.4515681862831116, 0.23...        waffles
# 313  [-1.9700900316238403, -1.1085718870162964, -1....        waffles
# 314  [-0.31929701566696167, 0.08910733461380005, 0....        waffles
# 315  [0.2025827169418335, 0.47957831621170044, 0.06...        waffles
#
#     text_names
# 0        1.txt
# 1       10.txt
# 2       11.txt
# 3       12.txt
# 4       13.txt
# 5       14.txt
# 6       15.txt
# 7        2.txt
# 8        3.txt
# 9        4.txt
# 10       5.txt
# 11       6.txt
# 12       7.txt
# 13       8.txt
# 14       9.txt
# 15       1.txt
# 16      10.txt
# 17      11.txt
# 18       2.txt
# 19       3.txt
# 20       4.txt
# 21       5.txt
# 22       6.txt
# 23       7.txt
# 24       8.txt
# 25       9.txt
# 26       1.txt
# 27       2.txt
# 28       3.txt
# 29       4.txt
# ..         ...
# 286      1.txt
# 287     10.txt
# 288      2.txt
# 289      3.txt
# 290      4.txt
# 291      5.txt
# 292      6.txt
# 293      7.txt
# 294      8.txt
# 295      9.txt
# 296      1.txt
# 297     10.txt
# 298      2.txt
# 299      3.txt
# 300      4.txt
# 301      5.txt
# 302      6.txt
# 303      7.txt
# 304      8.txt
# 305      9.txt
# 306      1.txt
# 307     10.txt
# 308      2.txt
# 309      3.txt
# 310      4.txt
# 311      5.txt
# 312      6.txt
# 313      7.txt
# 314      8.txt
# 315      9.txt
#
# [316 rows x 3 columns]
