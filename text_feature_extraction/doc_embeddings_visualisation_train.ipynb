# %%
import os
import pandas as pd
import numpy as np
from tensorflow.python import pywrap_tensorflow
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import plotly
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.plotly as py
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
def show_word_and_doc_embeddings():
    for tensor_name in var_to_shape_map:
        print("tensor_name: ", tensor_name) # get the variable name
        print(reader.get_tensor(tensor_name)) # get the variable
    
cwd=os.getcwd()
number_of_crossvalidation_run=1
models_folder_name = os.path.join(cwd,'models','train',str(number_of_crossvalidation_run))
path_to_preprocessed_texts=os.path.join(models_folder_name,'recipes_train_dataset.pkl')
path_to_saved_model = os.path.join(models_folder_name,'doc2vec_recipes_checkpoint.ckpt')
path_to_save_docs_embeddings_pkl=os.path.join(models_folder_name,'docs_extracted_features.pkl')

reader = pywrap_tensorflow.NewCheckpointReader(path_to_saved_model)
var_to_shape_map = reader.get_variable_to_shape_map() # 'var_to_shape_map' is a dictionary containing every saved tensor of the model
show_word_and_doc_embeddings()

doc_embeddings = reader.get_tensor('doc_embeddings')
doc_embeddings = doc_embeddings.tolist() 
    
df_preprocessed_texts = pd.read_pickle(path_to_preprocessed_texts)
# Out:
# tensor_name:  decoder_biases
# [-1.5411026e+00 -5.0227892e-01 -1.4502889e+00 -1.2695315e+00
#  -1.3550551e+00 -1.1592547e-01 -4.5815989e-01 -1.1242820e+00
#  -1.6408395e+00 -1.7603871e+00 -1.0597020e+00 -1.8340950e-01
#  -1.2039973e+00 -2.4376498e-01 -1.1498604e+00  5.2468807e-01
#  -7.1577466e-01 -4.8303908e-01 -7.3760813e-01 -8.2097888e-01
#  -1.2400152e-01 -1.6376958e+00 -1.2858709e+00 -6.8941802e-01
#  -1.2627616e+00  1.0663351e-01 -8.0047596e-01 -8.1850064e-01
#  -4.8799816e-01 -1.2243888e+00 -7.2024423e-01 -1.2875834e+00
#  -1.5179114e+00 -1.0307832e+00 -1.2838905e+00 -1.7585590e+00
#  -1.0829617e+00 -1.6417009e+00 -1.1768509e+00 -8.8305533e-01
#  -1.3362029e+00 -1.4588698e+00 -1.1969390e+00 -1.6380873e+00
#  -3.1685847e-01 -1.4122856e+00 -2.3228664e+00  1.5605085e-01
#  -1.0195348e+00 -3.8065448e-01 -1.3400854e+00 -6.6588914e-01
#  -1.0301884e+00 -1.3464800e+00 -1.2886844e+00  1.7022997e-01
#  -1.0519398e+00 -1.4500397e+00 -1.1796902e+00 -1.3331289e+00
#  -1.0136118e+00 -1.4480509e+00 -1.0537870e+00  1.3180796e+00
#  -1.5579472e+00 -1.2000434e+00 -1.1693772e+00 -4.7547576e-01
#  -1.3946500e+00 -7.7612329e-01 -1.6143056e+00 -2.8776807e-01
#  -1.5835369e+00 -1.0510223e+00 -1.9414761e+00 -8.0206913e-01
#   9.2746311e-01 -9.0410113e-01 -1.2324567e+00  2.4379876e-01
#  -8.1691176e-01 -7.4687648e-01 -1.3126016e+00 -1.0044798e+00
#   1.5202418e-01 -1.5639033e+00 -1.7860729e+00 -2.0560472e+00
#  -5.8049268e-01 -7.7864349e-02 -1.4771477e+00 -8.3485246e-01
#   -1.8259071 ]
#  [-0.35951674 -1.9170965   0.14980748 ...  1.2531807   0.7351144
#   -0.81338286]
#  [-1.8282828  -1.1303542   0.2403738  ...  0.18064134 -0.37028372
#   -0.57124025]
#  ...
#  [ 0.06142383 -0.4224579  -0.71129364 ...  0.6132714  -0.39184216
#    1.6800978 ]
#  [-1.6466497  -0.4515682   0.23712814 ...  0.16389151  0.13004278
#    0.09575307]
#  [-0.31929702  0.08910733  0.45950502 ...  0.64740914 -0.7659907
#   -0.21637559]]

# %%
 dict_doc_embeddings = {
    'text_names': df_preprocessed_texts.text_names,
    'labels' : df_preprocessed_texts.labels,
    'doc_embeddings' : doc_embeddings
}
    

df_doc_embeddings=pd.DataFrame(dict_doc_embeddings)
df_doc_embeddings
# Out:
#                                         doc_embeddings         labels  \
# 1    [-0.24955427646636963, -0.9826421737670898, 1....      apple_pie
# 2    [-0.3595167398452759, -1.917096495628357, 0.14...      apple_pie
# 3    [-1.8282828330993652, -1.1303541660308838, 0.2...      apple_pie
# 5    [-0.266160786151886, -0.8897382616996765, -0.2...      apple_pie
# 6    [-0.6199544668197632, -2.098040819168091, 0.46...      apple_pie
# 7    [-0.9792886972427368, -1.758888840675354, 0.88...      apple_pie
# 9    [-1.346577525138855, -1.6965863704681396, 0.44...      apple_pie
# 10   [-0.40207439661026, -0.460137277841568, 0.1327...      apple_pie
# 11   [-0.7689167261123657, -0.6829455494880676, -0....      apple_pie
# 12   [-0.28463613986968994, -1.9537571668624878, -0...      apple_pie
# 13   [-0.08445477485656738, -1.5573848485946655, 0....      apple_pie
# 14   [-0.027063369750976562, -1.3993891477584839, 1...      apple_pie
# 15   [0.27984189987182617, 0.6530324816703796, -1.5...     cheesecake
# 16   [0.43558064103126526, 0.49440622329711914, -1....     cheesecake
# 17   [1.2922141551971436, -0.9313622713088989, -1.0...     cheesecake
# 18   [1.4885790348052979, 1.096511721611023, 0.2870...     cheesecake
# 19   [-0.09589019417762756, 0.8855007886886597, -0....     cheesecake
# 21   [0.8093789219856262, -0.7551910877227783, -1.2...     cheesecake
# 23   [-1.3935028314590454, 1.2817113399505615, -0.6...     cheesecake
# 24   [-0.5860337615013123, -0.3248964250087738, -0....     cheesecake
# 25   [-1.407525658607483, -0.028818387538194656, -1...     cheesecake
# 26   [-0.8508996367454529, -0.7636610865592957, 0.5...  chicken_curry
# 27   [0.21264955401420593, -0.992591917514801, -0.9...  chicken_curry
# 29   [-0.8686707615852356, -0.8378395438194275, 0.9...  chicken_curry
# 30   [0.5654277801513672, -0.6537221670150757, -0.3...  chicken_curry
# 31   [0.19433188438415527, 0.005292427260428667, 0....  chicken_curry
# 32   [0.3772735893726349, -0.49523743987083435, -0....  chicken_curry
# 33   [-1.5440115928649902, -0.4526028335094452, 1.5...  chicken_curry
# 34   [1.153456449508667, 1.4980289936065674, 1.2875...  chicken_wings
# 35   [-0.23051577806472778, 1.5128908157348633, 0.9...  chicken_wings
# ..                                                 ...            ...
# 279  [2.3203554153442383, -0.9959041476249695, -1.1...          sushi
# 280  [-0.19752992689609528, 0.4873999059200287, 0.3...          sushi
# 281  [0.308861643075943, -1.1704049110412598, -0.69...          sushi
# 282  [-0.31542375683784485, 0.4985199570655823, -2....          sushi
# 283  [2.215823173522949, -1.8079705238342285, -2.08...          sushi
# 285  [0.08140668272972107, -0.7020478248596191, -0....          sushi
# 286  [1.6704697608947754, 2.553302049636841, -2.481...          tacos
# 288  [-0.16742615401744843, 1.983201026916504, 0.84...          tacos
# 289  [0.3815311789512634, 2.0011582374572754, -0.54...          tacos
# 290  [1.2911945581436157, 2.0049774646759033, -1.13...          tacos
# 291  [1.2431716918945312, 0.5271018147468567, -0.59...          tacos
# 292  [-1.2440983057022095, 1.9036787748336792, -2.0...          tacos
# 294  [-0.7448776364326477, 1.6176127195358276, -0.0...          tacos
# 295  [0.004371568560600281, 1.332057237625122, 1.21...          tacos
# 296  [1.1422154903411865, 1.9577702283859253, -1.67...       tiramisu
# 297  [1.5070418119430542, 1.5975559949874878, -1.85...       tiramisu
# 298  [1.0471465587615967, 1.869505524635315, -2.043...       tiramisu
# 299  [-0.03557921200990677, 2.2737526893615723, -2....       tiramisu
# 300  [0.3640303909778595, 1.189726710319519, -0.874...       tiramisu
# 301  [-0.13649046421051025, 1.7855502367019653, -1....       tiramisu
# 304  [1.0407118797302246, 2.449871301651001, -0.714...       tiramisu
# 305  [1.1837632656097412, 0.31328344345092773, -3.1...       tiramisu
# 306  [-1.7231429815292358, 0.41761982440948486, -0....        waffles
# 307  [-0.3247416913509369, -0.7209973931312561, -0....        waffles
# 308  [0.02513846941292286, 0.033605534583330154, 0....        waffles
# 309  [0.9694137573242188, -1.0049406290054321, -0.8...        waffles
# 310  [1.0341912508010864, -0.0008001980022527277, 0...        waffles
# 311  [0.06142382696270943, -0.42245790362358093, -0...        waffles
# 312  [-1.646649718284607, -0.4515681862831116, 0.23...        waffles
# 314  [-0.31929701566696167, 0.08910733461380005, 0....        waffles
#
#     text_names
# 1       10.txt
# 2       11.txt
# 3       12.txt
# 5       14.txt
# 6       15.txt
# 7        2.txt
# 9        4.txt
# 10       5.txt
# 11       6.txt
# 12       7.txt
# 13       8.txt
# 14       9.txt
# 15       1.txt
# 16      10.txt
# 17      11.txt
# 18       2.txt
# 19       3.txt
# 21       5.txt
# 23       7.txt
# 24       8.txt
# 25       9.txt
# 26       1.txt
# 27       2.txt
# 29       4.txt
# 30       5.txt
# 31       6.txt
# 32       7.txt
# 33       8.txt
# 34       1.txt
# 35      10.txt
# ..         ...
# 279      3.txt
# 280      4.txt
# 281      5.txt
# 282      6.txt
# 283      7.txt
# 285      9.txt
# 286      1.txt
# 288      2.txt
# 289      3.txt
# 290      4.txt
# 291      5.txt
# 292      6.txt
# 294      8.txt
# 295      9.txt
# 296      1.txt
# 297     10.txt
# 298      2.txt
# 299      3.txt
# 300      4.txt
# 301      5.txt
# 304      8.txt
# 305      9.txt
# 306      1.txt
# 307     10.txt
# 308      2.txt
# 309      3.txt
# 310      4.txt
# 311      5.txt
# 312      6.txt
# 314      8.txt
#
# [264 rows x 3 columns]

# %%
doc_embeddings=df_doc_embeddings.doc_embeddings.values.tolist()
labels=df_doc_embeddings.labels.values.tolist()
text_names=df_doc_embeddings.text_names.values.tolist()

unique_labels=sorted(set(labels))
number_of_recipe_categories=len(unique_labels)
possible_category_indices=np.linspace(0,number_of_recipe_categories-1,number_of_recipe_categories,dtype=int)
labels2integers=dict(zip(unique_labels,possible_category_indices))

print(labels2integers)

category_indices=[]
for l in labels:
    category_index=labels2integers[l]
    category_indices.append(category_index)
# Out:
# {'cheesecake': 1, 'pancakes': 19, 'tacos': 24, 'garlic_bread': 11, 'deviled_eggs': 6, 'waffles': 26, 'frozen_yogurt': 10, 'fried_rice': 9, 'chicken_wings': 3, 'hamburger': 12, 'sushi': 23, 'macarons': 16, 'chicken_curry': 2, 'french_toast': 8, 'hummus': 13, 'dumplings': 7, 'steak': 22, 'onion_rings': 18, 'chocolate_mousse': 5, 'pizza': 20, 'chocolate_cake': 4, 'nachos': 17, 'sashimi': 21, 'apple_pie': 0, 'macaroni_and_cheese': 15, 'tiramisu': 25, 'lasagna': 14}

# %%
#PCA

pca = PCA(n_components=2)
pca_2D_embeddings = pca.fit_transform(doc_embeddings)

dict_PCA_2D = {
    'pca-1' : pca_2D_embeddings[:,0],
    'pca-2' : pca_2D_embeddings[:,1],
    'labels' : labels,
    'category_indices': category_indices,
    'text_names': text_names
}

df_PCA_2D=pd.DataFrame(dict_PCA_2D)

# %%
traces=[]

for n in range(0,number_of_recipe_categories):
    df_category=df_PCA_2D[(df_PCA_2D.category_indices==n)]
    point_name=str(df_category.labels[df_category.index[0]])
    trace = go.Scatter(
    x=df_category['pca-1'],
    y=df_category['pca-2'],
    mode='markers',
    marker=dict(
        colorscale='Viridis',
        opacity=0.7,
        line=dict(color='rgb(140, 140, 170)')
    ),
    name=point_name,
    text=df_category['text_names'],
    )

    traces.append(trace)

layout = go.Layout(
    title='PCA reduction: 2D features',
    hovermode='closest',
    margin=dict(
       l=30,
       r=30,
       b=30,
       t=30
    ),
      scene = dict(
        xaxis = dict(
            title='pca-1',
       ),
       yaxis = dict(
           title='pca-2',
       ),
    ),
 
)

fig = go.Figure(data=traces, layout=layout)
iplot(fig)
# Out:
# <div id="1bc69131-091c-4020-8ba0-b5243db37245" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1bc69131-091c-4020-8ba0-b5243db37245", [{"x": [0.985511295277797, 0.7843697638211092, 1.190392213970685, 1.4885023092532048, 0.6401842306084683, 2.330594233983922, 1.190960964331484, 1.4094356206474852, 0.3614920738756614, 0.6919839473819445, 0.6347012738172207, 0.3178302282396656], "y": [-0.5334849702539646, 1.1506674941423418, -0.7291083397775663, 1.0446618887136676, 0.19550533886827448, 0.4379542373509434, 0.22339724771270153, -0.7287433829785369, 0.14631378723655317, 0.3884662488640535, -0.03362599908881231, 0.4919873937460846], "marker": {"line": {"color": "rgb(140, 140, 170)"}, "colorscale": "Viridis", "opacity": 0.7}, "text": ["10.txt", "11.txt", "12.txt", "14.txt", "15.txt", "2.txt", "4.txt", "5.txt", "6.txt", "7.txt", "8.txt", "9.txt"], "mode": "markers", "uid": "da1a439a-6646-490e-af5f-e429e87e0103", "name": "apple_pie", "type": "scatter"}, {"x": [1.4754210817674676, 1.026842613291861, 1.2713043980434255, 2.5615248876497008, 1.9245828682539217, 2.646911056536984, 1.4938383598340939, 2.394538434900245, 2.6516596003755035], "y": [0.47044649699674235, -0.12473929900141198, 0.8529679612949351, -0.7202904784751781, 0.19296099636455985, 0.5044797898714259, 0.35704768825494415, 0.6973374255540806, 1.0982213205963507], "marker": {"line": {"color": "rgb(140, 140, 170)"}, "colorscale": "Viridis", "opacity": 0.7}, "text": ["1.txt", "10.txt", "11.txt", "2.txt", "3.txt", "5.txt", "7.txt", "8.txt", "9.txt"], "mode": "markers", "uid": "a2c85bcb-f968-4e50-9b83-4f244943fe0a", "name": "cheesecake", "type": "scatter"}, {"x": [-2.4273275116460242, -2.4238736679656694, -2.8816081991545044, -2.4234940374950926, -2.012403206811805, -1.6809887056653707, -2.3754417594623654], "y": [-0.26288601026754094, 0.06890358649265574, -0.015781701396823826, 0.3941719318597917, 0.0042447724788889744, 0.12659586655866034, -0.8035293202350893], "marker": {"line": {"color": "rgb(140, 140, 170)"}, "colorscale": "Viridis", "opacity": 0.7}, "text": ["1.txt", "2.txt", "4.txt", "5.txt", "6.txt", "7.txt", "8.txt"], "mode": "markers", "uid": "a9d22a5c-62f1-429b-a3da-59438dea3586", "name": "chicken_curry", "type": "scatter"}, {"x": [-0.557638329650914, -1.1931029229797383, -0.38804430311638927, -1.0388340637645894, -0.7445274791430685, -0.9335583757779227, -1.4296907268017316, -1.0172896115764196, -1.1615397626355535, -1.679543849079835, -0.5059878438022766, -1.4987789758256151, -1.2904618895963373, -1.1458220023279104], "y": [-1.7652990583298092, -1.6583962001637824, -0.4899164424746871, -1.3521152056396886, -0.3809119417469899, -0.1443397922691132, -1.4192198820596884, -1.6081218929246235, -1.507568260085975, -0.9395640645846844, -0.47037242476249425, -0.9050626123103966, -1.2402321101002327, -1.0102053598744303], "marker": {"line": {"color": "rgb(140, 140, 170)"}, "colorscale": "Viridis", "opacity": 0.7}, "text": ["1.txt", "10.txt", "11.txt", "12.txt", "15.txt", "16.txt", "17.txt", "2.txt", "3.txt", "4.txt", "5.txt", "7.txt", "8.txt", "9.txt"], "mode": "markers", "uid": "8e914e80-7cf5-4f70-ba9d-6891af8a3129", "name": "chicken_wings", "type": "scatter"}, {"x": [1.8668989212411873, 2.3198477460219054, 1.8205352671703725, 1.7222349965203603, 2.6250038202658166, 3.7543260233970455, 2.7071922788107385, 2.063252834166122], "y": [0.5660924358086372, -0.396108231056763, -0.15244156246594795, 0.5483021024948694, 0.5110271430779914, -0.9374645977976405, -1.1542228945363087, -0.17042651824855062], "marker": {"line": {"color": "rgb(140, 140, 170)"}, "colorscale": "Viridis", "opacity": 0.7}, "text": ["1.txt", "10.txt", "2.txt", "4.txt", "5.txt", "6.txt", "7.txt", "8.txt"], "mode": "markers", "uid": "bf7737cd-9165-4e43-961d-19bed40fcad9", "name": "chocolate_cake", "type": "scatter"}, {"x": [1.480 ...

# %%
#t-SNE 2D
    
tsne2D = TSNE(perplexity=15, n_components=2, verbose=2, init='pca', n_iter=2000,
                  n_iter_without_progress=500, learning_rate=5,method='exact')
tsne_2D_embeddings = tsne2D.fit_transform(doc_embeddings)
    
dict_TSNE_2D = {
    'pca-1' : tsne_2D_embeddings[:,0],
    'pca-2' : tsne_2D_embeddings[:,1],
    'labels' : labels,
    'category_indices': category_indices,
    'text_names': text_names
}

df_TSNE_2D=pd.DataFrame(dict_TSNE_2D)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 264 / 264
# [t-SNE] Mean sigma: 2.215358
# [t-SNE] Iteration 50: error = 62.8756296, gradient norm = 0.0004590 (50 iterations in 0.299s)
# [t-SNE] Iteration 100: error = 62.8756596, gradient norm = 0.0000000 (50 iterations in 0.241s)
# [t-SNE] Iteration 100: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 100 iterations with early exaggeration: 62.875660
# [t-SNE] Iteration 150: error = 1.6715302, gradient norm = 0.0193889 (50 iterations in 0.258s)
# [t-SNE] Iteration 200: error = 0.7782454, gradient norm = 0.0030911 (50 iterations in 0.232s)
# [t-SNE] Iteration 250: error = 0.6682302, gradient norm = 0.0020222 (50 iterations in 0.245s)
# [t-SNE] Iteration 300: error = 0.6242831, gradient norm = 0.0008596 (50 iterations in 0.234s)
# [t-SNE] Iteration 350: error = 0.6036801, gradient norm = 0.0005167 (50 iterations in 0.228s)
# [t-SNE] Iteration 400: error = 0.5920196, gradient norm = 0.0003604 (50 iterations in 0.231s)
# [t-SNE] Iteration 450: error = 0.5847408, gradient norm = 0.0002708 (50 iterations in 0.229s)
# [t-SNE] Iteration 500: error = 0.5796695, gradient norm = 0.0002291 (50 iterations in 0.230s)
# [t-SNE] Iteration 550: error = 0.5750476, gradient norm = 0.0002500 (50 iterations in 0.236s)
# [t-SNE] Iteration 600: error = 0.5691250, gradient norm = 0.0002960 (50 iterations in 0.232s)
# [t-SNE] Iteration 650: error = 0.5648598, gradient norm = 0.0002073 (50 iterations in 0.229s)
# [t-SNE] Iteration 700: error = 0.5623938, gradient norm = 0.0001505 (50 iterations in 0.240s)
# [t-SNE] Iteration 750: error = 0.5607130, gradient norm = 0.0001137 (50 iterations in 0.242s)
# [t-SNE] Iteration 800: error = 0.5595248, gradient norm = 0.0000917 (50 iterations in 0.239s)
# [t-SNE] Iteration 850: error = 0.5586065, gradient norm = 0.0000795 (50 iterations in 0.228s)
# [t-SNE] Iteration 900: error = 0.5578148, gradient norm = 0.0000763 (50 iterations in 0.220s)
# [t-SNE] Iteration 950: error = 0.5570127, gradient norm = 0.0000849 (50 iterations in 0.233s)
# [t-SNE] Iteration 1000: error = 0.5561212, gradient norm = 0.0000817 (50 iterations in 0.229s)
# [t-SNE] Iteration 1050: error = 0.5554671, gradient norm = 0.0000724 (50 iterations in 0.236s)
# [t-SNE] Iteration 1100: error = 0.5548373, gradient norm = 0.0000742 (50 iterations in 0.227s)
# [t-SNE] Iteration 1150: error = 0.5540794, gradient norm = 0.0000839 (50 iterations in 0.234s)
# [t-SNE] Iteration 1200: error = 0.5532436, gradient norm = 0.0000795 (50 iterations in 0.238s)
# [t-SNE] Iteration 1250: error = 0.5524285, gradient norm = 0.0000955 (50 iterations in 0.239s)
# [t-SNE] Iteration 1300: error = 0.5505732, gradient norm = 0.0001851 (50 iterations in 0.230s)
# [t-SNE] Iteration 1350: error = 0.5474643, gradient norm = 0.0001393 (50 iterations in 0.237s)
# [t-SNE] Iteration 1400: error = 0.5469729, gradient norm = 0.0000932 (50 iterations in 0.242s)
# [t-SNE] Iteration 1450: error = 0.5466625, gradient norm = 0.0000611 (50 iterations in 0.237s)
# [t-SNE] Iteration 1500: error = 0.5464663, gradient norm = 0.0000464 (50 iterations in 0.238s)
# [t-SNE] Iteration 1550: error = 0.5463141, gradient norm = 0.0000420 (50 iterations in 0.241s)
# [t-SNE] Iteration 1600: error = 0.5461724, gradient norm = 0.0000396 (50 iterations in 0.234s)
# [t-SNE] Iteration 1650: error = 0.5460296, gradient norm = 0.0000373 (50 iterations in 0.240s)
# [t-SNE] Iteration 1700: error = 0.5458838, gradient norm = 0.0000350 (50 iterations in 0.234s)
# [t-SNE] Iteration 1750: error = 0.5457363, gradient norm = 0.0000333 (50 iterations in 0.224s)
# [t-SNE] Iteration 1800: error = 0.5455904, gradient norm = 0.0000314 (50 iterations in 0.227s)
# [t-SNE] Iteration 1850: error = 0.5454465, gradient norm = 0.0000296 (50 iterations in 0.231s)
# [t-SNE] Iteration 1900: error = 0.5453050, gradient norm = 0.0000285 (50 iterations in 0.232s)
# [t-SNE] Iteration 1950: error = 0.5451675, gradient norm = 0.0000272 (50 iterations in 0.235s)
# [t-SNE] Iteration 2000: error = 0.5450357, gradient norm = 0.0000260 (50 iterations in 0.244s)
# [t-SNE] KL divergence after 2000 iterations: 0.545036

# %%
traces=[]

for n in range(0,number_of_recipe_categories):
    df_category=df
txt", "4.txt", "5.txt", "6.txt", "7.txt", "8.txt"], "mode": "markers", "uid": "a2214686-3ecd-46a1-be56-f2b5df123c7d", "name": "chocolate_cake", "type": "scatter"}, {"x": [30.397090911865234, 32.301063537597656, 33.95818328857422, 25.852994918823242, 3 ...

# %%
dict_docs_extracted_features = {
    'text_names': text_names,
    'labels' : labels,
    'features' : doc_embeddings   
}

df_docs_extracted_features=pd.DataFrame(dict_docs_extracted_features)
df_docs_extracted_features.index=df_doc_embeddings.index

print("Saving extracted features pandas dataframe to: ", path_to_save_docs_embeddings_pkl)
df_docs_extracted_features.to_pickle(path_to_save_docs_embeddings_pkl)

print("Extracted features pandas dataframe:")
df_docs_extracted_features
# Out:
# Saving extracted features pandas dataframe to:  /notebooks/school/text_feature_extraction/models/train/10/docs_extracted_features.pkl
# Extracted features pandas dataframe:
#                                               features         labels  \
# 1    [-0.24955427646636963, -0.9826421737670898, 1....      apple_pie
# 2    [-0.3595167398452759, -1.917096495628357, 0.14...      apple_pie
# 3    [-1.8282828330993652, -1.1303541660308838, 0.2...      apple_pie
# 5    [-0.266160786151886, -0.8897382616996765, -0.2...      apple_pie
# 6    [-0.6199544668197632, -2.098040819168091, 0.46...      apple_pie
# 7    [-0.9792886972427368, -1.758888840675354, 0.88...      apple_pie
# 9    [-1.346577525138855, -1.6965863704681396, 0.44...      apple_pie
# 10   [-0.40207439661026, -0.460137277841568, 0.1327...      apple_pie
# 11   [-0.7689167261123657, -0.6829455494880676, -0....      apple_pie
# 12   [-0.28463613986968994, -1.9537571668624878, -0...      apple_pie
# 13   [-0.08445477485656738, -1.5573848485946655, 0....      apple_pie
# 14   [-0.027063369750976562, -1.3993891477584839, 1...      apple_pie
# 15   [0.27984189987182617, 0.6530324816703796, -1.5...     cheesecake
# 16   [0.43558064103126526, 0.49440622329711914, -1....     cheesecake
# 17   [1.2922141551971436, -0.9313622713088989, -1.0...     cheesecake
# 18   [1.4885790348052979, 1.096511721611023, 0.2870...     cheesecake
# 19   [-0.09589019417762756, 0.8855007886886597, -0....     cheesecake
# 21   [0.8093789219856262, -0.7551910877227783, -1.2...     cheesecake
# 23   [-1.3935028314590454, 1.2817113399505615, -0.6...     cheesecake
# 24   [-0.5860337615013123, -0.3248964250087738, -0....     cheesecake
# 25   [-1.407525658607483, -0.028818387538194656, -1...     cheesecake
# 26   [-0.8508996367454529, -0.7636610865592957, 0.5...  chicken_curry
# 27   [0.21264955401420593, -0.992591917514801, -0.9...  chicken_curry
# 29   [-0.8686707615852356, -0.8378395438194275, 0.9...  chicken_curry
# 30   [0.5654277801513672, -0.6537221670150757, -0.3...  chicken_curry
# 31   [0.19433188438415527, 0.005292427260428667, 0....  chicken_curry
# 32   [0.3772735893726349, -0.49523743987083435, -0....  chicken_curry
# 33   [-1.5440115928649902, -0.4526028335094452, 1.5...  chicken_curry
# 34   [1.153456449508667, 1.4980289936065674, 1.2875...  chicken_wings
# 35   [-0.23051577806472778, 1.5128908157348633, 0.9...  chicken_wings
# ..                                                 ...            ...
# 279  [2.3203554153442383, -0.9959041476249695, -1.1...          sushi
# 280  [-0.19752992689609528, 0.4873999059200287, 0.3...          sushi
# 281  [0.308861643075943, -1.1704049110412598, -0.69...          sushi
# 282  [-0.31542375683784485, 0.4985199570655823, -2....          sushi
# 283  [2.215823173522949, -1.8079705238342285, -2.08...          sushi
# 285  [0.08140668272972107, -0.7020478248596191, -0....          sushi
# 286  [1.6704697608947754, 2.553302049636841, -2.481...          tacos
# 288  [-0.16742615401744843, 1.983201026916504, 0.84...          tacos
# 289  [0.3815311789512634, 2.0011582374572754, -0.54...          tacos
# 290  [1.2911945581436157, 2.0049774646759033, -1.13...          tacos
# 291  [1.2431716918945312, 0.5271018147468567, -0.59...          tacos
# 292  [-1.2440983057022095, 1.9036787748336792, -2.0...          tacos
# 294  [-0.7448776364326477, 1.6176127195358276, -0.0...          tacos
# 295  [0.004371568560600281, 1.332057237625122, 1.21...          tacos
# 296  [1.1422154903411865, 1.9577702283859253, -1.67...       tiramisu
# 297  [1.5070418119430542, 1.5975559949874878, -1.85...       tiramisu
# 298  [1.0471465587615967, 1.869505524635315, -2.043...       tiramisu
# 299  [-0.03557921200990677, 2.2737526893615723, -2....       tiramisu
# 300  [0.3640303909778595, 1.189726710319519, -0.874...       tiramisu
# 301  [-0.13649046421051025, 1.7855502367019653, -1....       tiramisu
# 304  [1.0407118797302246, 2.449871301651001, -0.714...       tiramisu
# 305  [1.1837632656097412, 0.31328344345092773, -3.1...       tiramisu
# 306  [-1.7231429815292358, 0.41761982440948486, -0....        waffles
# 307  [-0.3247416913509369, -0.7209973931312561, -0....        waffles
# 308  [0.02513846941292286, 0.033605534583330154, 0....        waffles
# 309  [0.9694137573242188, -1.0049406290054321, -0.8...        waffles
# 310  [1.0341912508010864, -0.0008001980022527277, 0...        waffles
# 311  [0.06142382696270943, -0.42245790362358093, -0...        waffles
# 312  [-1.646649718284607, -0.4515681862831116, 0.23...        waffles
# 314  [-0.31929701566696167, 0.08910733461380005, 0....        waffles
#
#     text_names
# 1       10.txt
# 2       11.txt
# 3       12.txt
# 5       14.txt
# 6       15.txt
# 7        2.txt
# 9        4.txt
# 10       5.txt
# 11       6.txt
# 12       7.txt
# 13       8.txt
# 14       9.txt
# 15       1.txt
# 16      10.txt
# 17      11.txt
# 18       2.txt
# 19       3.txt
# 21       5.txt
# 23       7.txt
# 24       8.txt
# 25       9.txt
# 26       1.txt
# 27       2.txt
# 29       4.txt
# 30       5.txt
# 31       6.txt
# 32       7.txt
# 33       8.txt
# 34       1.txt
# 35      10.txt
# ..         ...
# 279      3.txt
# 280      4.txt
# 281      5.txt
# 282      6.txt
# 283      7.txt
# 285      9.txt
# 286      1.txt
# 288      2.txt
# 289      3.txt
# 290      4.txt
# 291      5.txt
# 292      6.txt
# 294      8.txt
# 295      9.txt
# 296      1.txt
# 297     10.txt
# 298      2.txt
# 299      3.txt
# 300      4.txt
# 301      5.txt
# 304      8.txt
# 305      9.txt
# 306      1.txt
# 307     10.txt
# 308      2.txt
# 309      3.txt
# 310      4.txt
# 311      5.txt
# 312      6.txt
# 314      8.txt
#
# [264 rows x 3 columns]
