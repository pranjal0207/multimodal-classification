# %%
import os
import re
import numpy as np
import pandas as pd

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

import plotly
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.plotly as py

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
custom_color_map=[
    "#9370DB", "#EE82EE", "#6495ED", "#DB7093", "#1E90FF", "#40E0D0", "#008B8B",
    "#2E8B57", "#00FF00", "#6B8E23", "#F0E68C", "#DAA520", "#FF8C00", "#FFA07A",
    "#FF7F50", "#DC143C", "#800000", "#D2691E", "#BC8F8F", "#5F9EA0", "#9ACD32",
    "#FFA500", "#FFD700", "#B22222", "#4B0082", "#00FFFF", "#808080", "#000080",
    "#000000", "#008080", "#FF0000", "#800000", "#FFF5EE", "#FFEFD5", "#5F9EA0",
]
default_color="#5F9EA0"

# %%
cwd=os.getcwd()
image_dir = os.path.join(cwd,'data/recipes_splitted/images')

df_extracted_features = pd.read_pickle(os.path.join(image_dir,"extracted_features.pkl"))
#print("Extraced features from images: \n", df_extracted_features)

# %%
features=df_extracted_features['features'].values.tolist()
labels=df_extracted_features['labels'].values.tolist()
image_names=df_extracted_features['image_names'].values.tolist()

unique_labels=list(set(labels))
number_of_colors=len(unique_labels)
possible_color_indicies=np.linspace(0,number_of_colors-1,number_of_colors,dtype=int)
labels2color_indices=dict(zip(unique_labels,possible_color_indicies))

print(labels2color_indices)

color_indicies=[]
for l in labels:
    color_index=labels2color_indices[l]
    color_indicies.append(color_index)
# Out:
# {'sushi': 11, 'pancakes': 12, 'chocolate_cake': 1, 'chocolate_mousse': 13, 'pizza': 23, 'apple_pie': 15, 'chicken_curry': 16, 'macaroni_and_cheese': 2, 'cheesecake': 0, 'macarons': 17, 'steak': 18, 'hummus': 19, 'nachos': 20, 'chicken_wings': 3, 'tiramisu': 4, 'hamburger': 21, 'onion_rings': 8, 'frozen_yogurt': 5, 'sashimi': 6, 'garlic_bread': 24, 'fried_rice': 25, 'dumplings': 22, 'deviled_eggs': 7, 'french_toast': 26, 'tacos': 9, 'lasagna': 14, 'waffles': 10}

# %%
#PCA

pca = PCA(n_components=2)
pca_2D_embeddings = pca.fit_transform(features)

dict_PCA_2D = {
    'pca-1' : pca_2D_embeddings[:,0],
    'pca-2' : pca_2D_embeddings[:,1],
    'labels' : labels,
    'color_indicies': color_indicies,
    'image_names': image_names
}

df_PCA_2D=pd.DataFrame(dict_PCA_2D)
#print(df_2D_PCA)

# %%
traces=[]

for n in range(0,number_of_colors):
    df_category=df_PCA_2D[(df_PCA_2D.color_indicies==n)]
    point_name=str(df_category['labels'][df_category.index[0]])
    color=custom_color_map[n] if n < len(custom_color_map) else default_color
    trace = go.Scatter(
    x=df_category['pca-1'],
    y=df_category['pca-2'],
    mode='markers',
    marker=dict(
        color=color,
        opacity=0.7,
        line=dict(color='rgb(140, 140, 170)')
    ),
    name=point_name,
    text=df_category['image_names'],
    )

    traces.append(trace)

layout = go.Layout(
    title='PCA reduction: 2D features',
    hovermode='closest',
    margin=dict(
       l=30,
       r=30,
       b=30,
       t=30
    ),
      scene = dict(
        xaxis = dict(
            title='pca-1',
       ),
       yaxis = dict(
           title='pca-2',
       ),
    ),
 
)

fig = go.Figure(data=traces, layout=layout)
iplot(fig)
# Out:
# <div id="df0024c7-380e-441b-a6e5-1aaebfed4436" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("df0024c7-380e-441b-a6e5-1aaebfed4436", [{"mode": "markers", "y": [-8.281264190434253, -3.887236813709431, -7.3471432505342475, -5.4720414983097205, -6.732753324974348, -1.6225703639101603, -0.5931274875201668, 0.1614070629601697, -2.2626516857348866, 1.8987602504048724, -0.16067266409896133], "type": "scatter", "x": [4.311289507069973, -0.4711052890144342, 2.77946390042358, 11.086850383358005, 2.5620770802831863, -2.256030695133846, -3.5311679708883443, -4.573816722750084, -1.8431066310476203, 1.5003264100115592, -5.337667034815047], "name": "cheesecake", "text": ["1-1.jpg", "10-1.jpg", "11-1.jpg", "2-1.jpg", "3-1.jpg", "4-1.jpg", "5-1.jpg", "6-1.jpg", "7-1.jpg", "8-1.jpg", "9-1.jpg"], "marker": {"line": {"color": "rgb(140, 140, 170)"}, "opacity": 0.7, "color": "

# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 431 / 431
# [t-SNE] Mean sigma: 3.388352
# [t-SNE] Iteration 50: error = 57.9811391, gradient norm = 0.0754622 (50 iterations in 0.482s)
# [t-SNE] Iteration 100: error = 58.3444784, gradient norm = 0.0282654 (50 iterations in 0.467s)
# [t-SNE] Iteration 150: error = 58.1339095, gradient norm = 0.0037065 (50 iterations in 0.488s)
# [t-SNE] Iteration 200: error = 58.1471815, gradient norm = 0.0002623 (50 iterations in 0.436s)
# [t-SNE] Iteration 250: error = 58.1472798, gradient norm = 0.0000227 (50 iterations in 0.502s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 58.147280
# [t-SNE] Iteration 300: error = 0.8411403, gradient norm = 0.0038578 (50 iterations in 0.452s)
# [t-SNE] Iteration 350: error = 0.7218144, gradient norm = 0.0009853 (50 iterations in 0.445s)
# [t-SNE] Iteration 400: error = 0.6923413, gradient norm = 0.0004169 (50 iterations in 0.438s)
# [t-SNE] Iteration 450: error = 0.6805543, gradient norm = 0.0002351 (50 iterations in 0.438s)
# [t-SNE] Iteration 500: error = 0.6751766, gradient norm = 0.0001385 (50 iterations in 0.441s)
# [t-SNE] Iteration 550: error = 0.6725980, gradient norm = 0.0000868 (50 iterations in 0.457s)
# [t-SNE] Iteration 600: error = 0.6712378, gradient norm = 0.0000578 (50 iterations in 0.444s)
# [t-SNE] Iteration 650: error = 0.6704710, gradient norm = 0.0000422 (50 iterations in 0.427s)
# [t-SNE] Iteration 700: error = 0.6699862, gradient norm = 0.0000361 (50 iterations in 0.429s)
# [t-SNE] Iteration 750: error = 0.6695724, gradient norm = 0.0000390 (50 iterations in 0.436s)
# [t-SNE] Iteration 800: error = 0.6691763, gradient norm = 0.0000320 (50 iterations in 0.440s)
# [t-SNE] Iteration 850: error = 0.6689996, gradient norm = 0.0000164 (50 iterations in 0.448s)
# [t-SNE] Iteration 900: error = 0.6689302, gradient norm = 0.0000178 (50 iterations in 0.438s)
# [t-SNE] Iteration 950: error = 0.6688546, gradient norm = 0.0000218 (50 iterations in 0.447s)
# [t-SNE] Iteration 1000: error = 0.6685889, gradient norm = 0.0000884 (50 iterations in 0.442s)
# [t-SNE] Iteration 1050: error = 0.6680407, gradient norm = 0.0000340 (50 iterations in 0.441s)
# [t-SNE] Iteration 1100: error = 0.6679953, gradient norm = 0.0000131 (50 iterations in 0.434s)
# [t-SNE] Iteration 1150: error = 0.6679830, gradient norm = 0.0000061 (50 iterations in 0.439s)
# [t-SNE] Iteration 1200: error = 0.6679788, gradient norm = 0.0000033 (50 iterations in 0.440s)
# [t-SNE] Iteration 1250: error = 0.6679769, gradient norm = 0.0000023 (50 iterations in 0.437s)
# [t-SNE] Iteration 1300: error = 0.6679756, gradient norm = 0.0000019 (50 iterations in 0.443s)
# [t-SNE] Iteration 1350: error = 0.6679747, gradient norm = 0.0000015 (50 iterations in 0.432s)
# [t-SNE] Iteration 1400: error = 0.6679741, gradient norm = 0.0000012 (50 iterations in 0.498s)
# [t-SNE] Iteration 1450: error = 0.6679737, gradient norm = 0.0000010 (50 iterations in 0.439s)
# [t-SNE] Iteration 1500: error = 0.6679734, gradient norm = 0.0000008 (50 iterations in 0.445s)
# [t-SNE] Iteration 1550: error = 0.6679732, gradient norm = 0.0000006 (50 iterations in 0.433s)
# [t-SNE] Iteration 1600: error = 0.6679731, gradient norm = 0.0000005 (50 iterations in 0.436s)
# [t-SNE] Iteration 1650: error = 0.6679730, gradient norm = 0.0000004 (50 iterations in 0.444s)
1.jpg", "2-1.jpg", "3-1.jpg", "4-1.jpg", "5-1.jpg", "6-1.jpg", "7-1.jpg", "8-1.jpg", "9-1.jpg"], "marker": {"line": {"color": "rgb(140, 140, 170)"}, "opacity": 0.7, "color": "#6495ED"}, "uid": "01c2f7b2-f7ab-4e54-b8ea-5c421cc7dd60"}, {"mode": "markers", "y": [16.327964782714844, 15.46865177154541, 17.40854263305664, 11.184748649597168, 13.910009384155273, 14.714133262634277, 14.364568710327148, 13.846986770629883, 18.188232421875, 12.462150573730469, 16.21438980102539, 8.578377723693848, 16.63298988342285, 2.297544240951538, 12.6302490234375, 8.599837303161621, 13.18886947631836], "type": "scatter", "x": [14.805194854736328, 15.763757705688477, 15.793197631835938, 16.109413146972656, 16.673274993896484, 17.077484130859375, 14.844842910766602, 12.94666576385498, 17.741619110107422, 17.761140823364258, 17.478477478027344, 7.226832866668701, 16.452804565429688, 1.5684412717819214, 13.645997047424316, -2.260643243789673, 15.777125358581543], "name": "chicken_wings", "text": ["1-1.jpg", "10-1.jpg", "11-1.jpg", "12-1.jpg", "13-1.jpg", "14-1.jpg", "15-1.jpg", "16-1.jpg", "17-1.jpg", "2-1.jpg", "3-1.jpg", "4-1.jpg", "5-1.jpg", "6-1.jpg", "7-1.jpg", "8-1.jpg", "9-1.jpg"], "marker": {"line": {"color": "rgb(140, 140, 170)"}, "opacity": 0.7, "color": "#DB7093"}, "uid": "e3756b04-2619-4dd8-8bfd-dcf9f047bf64"}, {"mode": "markers", "y": [-27.765838623046875, -15. ...

# %%
    #t-SNE 3D
    
    tsne_3D = TSNE(perplexity=20, n_components=3, verbose=2, init='pca',
                   n_iter=4000, n_iter_without_progress=1000, learning_rate=25, method='exact')
    low_dim_embs_3D = tsne_3D.fit_transform(features)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 431 / 431
# [t-SNE] Mean sigma: 3.089564
# [t-SNE] Iteration 50: error = 62.8055056, gradient norm = 0.1777025 (50 iterations in 0.893s)
# [t-SNE] Iteration 100: error = 63.1122346, gradient norm = 0.0123698 (50 iterations in 0.865s)
# [t-SNE] Iteration 150: error = 62.0094509, gradient norm = 0.0667486 (50 iterations in 0.839s)
# [t-SNE] Iteration 200: error = 62.6366243, gradient norm = 0.0081240 (50 iterations in 0.842s)
# [t-SNE] Iteration 250: error = 62.3777642, gradient norm = 0.0114675 (50 iterations in 0.835s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 62.377764
# [t-SNE] Iteration 300: error = 0.8349654, gradient norm = 0.0014841 (50 iterations in 0.846s)
# [t-SNE] Iteration 350: error = 0.7267047, gradient norm = 0.0004267 (50 iterations in 0.833s)
# [t-SNE] Iteration 400: error = 0.6762457, gradient norm = 0.0002844 (50 iterations in 0.841s)
# [t-SNE] Iteration 450: error = 0.6472876, gradient norm = 0.0001131 (50 iterations in 0.839s)
# [t-SNE] Iteration 500: error = 0.6406998, gradient norm = 0.0000784 (50 iterations in 0.827s)
# [t-SNE] Iteration 550: error = 0.6356345, gradient norm = 0.0000704 (50 iterations in 0.840s)
# [t-SNE] Iteration 600: error = 0.6299136, gradient norm = 0.0001032 (50 iterations in 0.820s)
# [t-SNE] Iteration 650: error = 0.6259712, gradient norm = 0.0001628 (50 iterations in 0.827s)
# [t-SNE] Iteration 700: error = 0.6206359, gradient norm = 0.0003225 (50 iterations in 0.838s)
# [t-SNE] Iteration 750: error = 0.6161259, gradient norm = 0.0007728 (50 iterations in 0.834s)
# [t-SNE] Iteration 800: error = 0.6058765, gradient norm = 0.0004553 (50 iterations in 0.842s)
# [t-SNE] Iteration 850: error = 0.6014497, gradient norm = 0.0002953 (50 iterations in 0.849s)
# [t-SNE] Iteration 900: error = 0.5997369, gradient norm = 0.0001239 (50 iterations in 0.841s)
# [t-SNE] Iteration 950: error = 0.5950843, gradient norm = 0.0000711 (50 iterations in 0.845s)
# [t-SNE] Iteration 1000: error = 0.5948217, gradient norm = 0.0000239 (50 iterations in 0.851s)
# [t-SNE] Iteration 1050: error = 0.5947340, gradient norm = 0.0000179 (50 iterations in 0.848s)
# [t-SNE] Iteration 1100: error = 0.5949790, gradient norm = 0.0000145 (50 iterations in 0.851s)
# [t-SNE] Iteration 1150: error = 0.5953979, gradient norm = 0.0000123 (50 iterations in 0.868s)
# [t-SNE] Iteration 1200: error = 0.5958546, gradient norm = 0.0000105 (50 iterations in 0.829s)
# [t-SNE] Iteration 1250: error = 0.5962346, gradient norm = 0.0000098 (50 iterations in 0.854s)
# [t-SNE] Iteration 1300: error = 0.5964511, gradient norm = 0.0000104 (50 iterations in 0.830s)
# [t-SNE] Iteration 1350: error = 0.5963076, gradient norm = 0.0000205 (50 iterations in 0.832s)
# [t-SNE] Iteration 1400: error = 0.5958181, gradient norm = 0.0000269 (50 iterations in 0.837s)
# [t-SNE] Iteration 1450: error = 0.5953377, gradient norm = 0.0000228 (50 iterations in 0.829s)
# [t-SNE] Iteration 1500: error = 0.5952320, gradient norm = 0.0000109 (50 iterations in 0.878s)
# [t-SNE] Iteration 1550: error = 0.5952424, gradient norm = 0.0000103 (50 iterations in 0.830s)
# [t-SNE] Iteration 1600: error = 0.5952553, gradient norm = 0.0000074 (50 iterations in 0.843s)
# [t-SNE] Iteration 1650: error = 0.5952834, gradient norm = 0.0000032 (50 iterations in 0.833s)
# [t-SNE] Iteration 1700: error = 0.5953281, gradient norm = 0.0000020 (50 iterations in 0.827s)
# [t-SNE] Iteration 1750: error = 0.5953742, gradient norm = 0.0000015 (50 iterations in 0.839s)
# [t-SNE] Iteration 1800: error = 0.5954152, gradient norm = 0.0000012 (50 iterations in 0.829s)
# [t-SNE] Iteration 1850: error = 0.5954482, gradient norm = 0.0000011 (50 iterations in 0.839s)
# [t-SNE] Iteration 1900: error = 0.5954718, gradient norm = 0.0000009 (50 iterations in 0.825s)
# [t-SNE] Iteration 1950: error = 0.5954878, gradient norm = 0.0000008 (50 iterations in 0.852s)
# [t-SNE] Iteration 2000: error = 0.5954975, gradient norm = 0.0000007 (50 iterations in 0.866s)
# [t-SNE] Iteration 2050: error = 0.5955043, gradient norm = 0.0000005 (50 iterations in 0.830s)
# [t-SNE] Iteration 2100: error = 0.5955092, gradient norm = 0.0000005 (50 iterations in 0.839s)
# [t-SNE] Iteration 2100: did not make any progress during the last 1000 episodes. Finished.
# [t-SNE] KL divergence after 2100 iterations: 0.595509

# %%
dict_TSNE_3D = {'pca-1' : low_dim_embs_3D[:,0],
     'pca-2' : low_dim_embs_3D[:,1],
     'pca-3' : low_dim_embs_3D[:,2],
     'labels' : labels,
     'colors' : color_indicies,
     'image_names': image_names}

df_3D=pd.DataFrame(dict_TSNE_3D)

# %%
traces=[]

for n in range(0,number_of_colors):
    df_category=df_3D[(df_3D.colors==n)]
    color=custom_color_map[n] if n < len(custom_color_map) else default_color
    point_name=str(df_category['labels'][df_category.index[0]])
    trace = go.Scatter3d(
    x=df_category['pca-1'],
    y=df_category['pca-2'],
    z=df_category['pca-3'],
    mode='markers',
    marker=dict(
        color=color,
        opacity=0.7,
        line=dict(color='rgb(140, 140, 170)')
    ),
    name=point_name,
    text=df_category['image_names'],
    )

    traces.append(trace)


data = traces

layout = go.Layout(
    title='t-SNE reduction: 3D features',
    margin=dict(
       l=30,
       r=30,
       b=30,
       t=30
    ),
      scene = dict(
        xaxis = dict(
            title='pca-1',
       ),
       yaxis = dict(
           title='pca-2',
       ),
        zaxis = dict(
            title='pca-3',
        ),
    ),
 
)


fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="6530c2bb-6a50-4c54-87ff-56da65c45a30" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("